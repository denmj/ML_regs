# %%
# %matplotlib inline
import os
import sys
import pickle

from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

import torchvision
from torchvision import models

import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset
import torch.optim as optim
from torchmetrics import Accuracy
from torchinfo import summary
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import VOCDetection

sys.path.append('../../')  
from Object_Detection.RCNN import selective_search
from Object_Detection.RCNN.bbox import calculate_iou
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# Settings 

torch.set_printoptions(precision=3)

# %%
voc_dataset = VOCDetection(root='./data', 
                           year='2012', 
                           image_set='train',
                           download=True, 
                        #    transform=transform
                           )
# Out:
# Using downloaded and verified file: ./data\VOCtrainval_11-May-2012.tar
# Extracting ./data\VOCtrainval_11-May-2012.tar to ./data

# %% [markdown]
# # Load model and its finetuned weights (PASCAL VOC)

# %%
# Step 1: Load the ResNet50 model without pretrained weights
resnet50 = models.resnet50(weights=False)

resnet50.fc = torch.nn.Linear(resnet50.fc.in_features, 20)
# Out:
# m:\ML\ML_regs\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Step 2: Load your finetuned weights
# Make sure that the path 'voc_finetune_resnet_weights.pth' is correct and accessible
resnet50.load_state_dict(torch.load('resnet50_pascal_voc.pth'))
# Out:
# <All keys matched successfully>

# %%
summary(model=resnet50, input_size=(1, 3, 227, 227), col_width=20,
                  col_names=['input_size', 'output_size', 'num_params', 'trainable'], row_settings=['var_names'], verbose=0)

# %%
class ResNet50Modified(nn.Module):
    def __init__(self, original_model):
        super(ResNet50Modified, self).__init__()
        # Adapt this line if your model was changed differently
        self.features = nn.Sequential(*list(original_model.children())[:-1])  # Typically removes the final fully connected layer and avg pooling layer

    def forward(self, x):
        x = self.features(x)
        return x

# Create the modified model with loaded weights
modified_resnet50 = ResNet50Modified(resnet50)

# Put the model in evaluation mode if you are doing inference or feature extraction
modified_resnet50.eval()

if torch.cuda.is_available():
    modified_resnet50 = modified_resnet50.cuda()

# %%
summary(model=modified_resnet50, input_size=(1, 3, 227, 227), col_width=20,
                  col_names=['input_size', 'output_size', 'num_params', 'trainable'], row_settings=['var_names'], verbose=0)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# ResNet50Modified (ResNet50Modified)           [1, 3, 227, 227]     [1, 2048, 1, 1]      --                   True
# ├─Sequential (features)                       [1, 3, 227, 227]     [1, 2048, 1, 1]      --                   True
# │    └─Conv2d (0)                             [1, 3, 227, 227]     [1, 64, 114, 114]    9,408                True
# │    └─BatchNorm2d (1)                        [1, 64, 114, 114]    [1, 64, 114, 114]    128                  True
# │    └─ReLU (2)                               [1, 64, 114, 114]    [1, 64, 114, 114]    --                   --
# │    └─MaxPool2d (3)                          [1, 64, 114, 114]    [1, 64, 57, 57]      --                   --
# │    └─Sequential (4)                         [1, 64, 57, 57]      [1, 256, 57, 57]     --                   True
# │    │    └─Bottleneck (0)                    [1, 64, 57, 57]      [1, 256, 57, 57]     75,008               True
# │    │    └─Bottleneck (1)                    [1, 256, 57, 57]     [1, 256, 57, 57]     70,400               True
# │    │    └─Bottleneck (2)                    [1, 256, 57, 57]     [1, 256, 57, 57]     70,400               True
# │    └─Sequential (5)                         [1, 256, 57, 57]     [1, 512, 29, 29]     --                   True
# │    │    └─Bottleneck (0)                    [1, 256, 57, 57]     [1, 512, 29, 29]     379,392              True
# │    │    └─Bottleneck (1)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    │    └─Bottleneck (2)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    │    └─Bottleneck (3)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    └─Sequential (6)                         [1, 512, 29, 29]     [1, 1024, 15, 15]    --                   True
# │    │    └─Bottleneck (0)                    [1, 512, 29, 29]     [1, 1024, 15, 15]    1,512,448            True
# │    │    └─Bottleneck (1)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (2)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (3)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (4)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (5)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    └─Sequential (7)                         [1, 1024, 15, 15]    [1, 2048, 8, 8]      --                   True
# │    │    └─Bottleneck (0)                    [1, 1024, 15, 15]    [1, 2048, 8, 8]      6,039,552            True
# │    │    └─Bottleneck (1)                    [1, 2048, 8, 8]      [1, 2048, 8, 8]      4,462,592            True
# │    │    └─Bottleneck (2)                    [1, 2048, 8, 8]      [1, 2048, 8, 8]      4,462,592            True
# │    └─AdaptiveAvgPool2d (8)                  [1, 2048, 8, 8]      [1, 2048, 1, 1]      --                   --
# =============================================================================================================================
# Total params: 23,508,032
# Trainable params: 23,508,032
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 4.63
# =============================================================================================================================
# Input size (MB): 0.62
# Forward/backward pass size (MB): 191.90
# Params size (MB): 94.03
# Estimated Total Size (MB): 286.55
# =============================================================================================================================

# %% [markdown]
# # Generate features

# %%
voc_dataset
# Out:
# Dataset VOCDetection
#     Number of datapoints: 5717
#     Root location: ./data

# %%
# Single image load from the VOC dataset and in numpy format

image, target = voc_dataset[0]
image_array = np.array(image)

# %%
preprocess = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def batch_process_features(model, regions):
    """ Process a batch of regions through the model """
    # Convert list of PIL images to tensor
    regions_tensor = torch.stack([preprocess(region) for region in regions]).cuda()
    
    # Extract features
    with torch.no_grad():
        features = model(regions_tensor)
    return features.cpu().numpy()

gs = selective_search.get_selective_search()

counter, start_index = 1800, 1800
svm_dataset = []
regression_dataset = []
# Assuming 'voc_dataset' is iterable with (image, annot)
for i in range(start_index, len(voc_dataset)):
    image, annot = voc_dataset[i]
    
    counter += 1
    # Counter for images processed
    print(f'Processing image {counter}')

    # Get proposals and annotations similar to your original code
    image_array = np.array(image)
    selective_search.config(gs, image_array, strategy='q')
    rects = selective_search.get_rects(gs)

    # Prepare annotations
    annotations = []
    for obj in annot['annotation']['object']:
        annotations.append({
            'class': obj['name'],
            'bbox': [int(obj['bndbox']['xmin']), int(obj['bndbox']['ymin']), int(obj['bndbox']['xmax']), int(obj['bndbox']['ymax'])]
        })

    # Collect regions for batch processing
    regions = [image.crop((x1, y1, x2, y2)) for x1, y1, x2, y2 in rects]

    # Process all regions at once in batches
    features = []
    for i in range(0, len(regions), 16):  # batch_size e.g., 32, 64, 128, 256, 512
        batch = regions[i:i + 16]
        batch_features = batch_process_features(modified_resnet50, batch)
        features.extend(batch_features)


    # Calculate IOUs and assign labels after extracting all features
    labels = []
    for proposal, feature in zip(rects, features):
        proposal_iou = {cls['class']: calculate_iou(proposal, cls['bbox']) for cls in annotations}
        best_iou = max(proposal_iou.values())
        if best_iou > 0.5:
            matched_class = max(proposal_iou, key=proposal_iou.get)
            labels.append((proposal, matched_class, 'positive'))
        else:
            labels.append((proposal, None, 'negative'))


    # Prepare datasets for SVM and regression

    for feature, label in zip(features, labels):
        if label[2] == 'positive':
            svm_dataset.append((feature, label[1]))
            ground_truth_bbox = next((item['bbox'] for item in annotations if item['class'] == label[1]), None)
            if ground_truth_bbox:
                tx = ground_truth_bbox[0] - label[0][0]
                ty = ground_truth_bbox[1] - label[0][1]
                tw = ground_truth_bbox[2] - label[0][2]
                th = ground_truth_bbox[3] - label[0][3]
                regression_dataset.append((feature, (tx, ty, tw, th)))
    print(f'Number of data in SVM dataset: {len(svm_dataset)}')
    print(f'Number of data in regression dataset: {len(regression_dataset)}')
    # break after 10 images
    if counter == 2200:
        break
# Out:
# Processing image 1801
# Number of data in SVM dataset: 261
# Number of data in regression dataset: 261
# Processing image 1802
# Number of data in SVM dataset: 271
# Number of data in regression dataset: 271
# Processing image 1803
# Number of data in SVM dataset: 350
# Number of data in regression dataset: 350
# Processing image 1804
# Number of data in SVM dataset: 393
# Number of data in regression dataset: 393
# Processing image 1805
# Number of data in SVM dataset: 558
# Number of data in regression dataset: 558
# Processing image 1806
# Number of data in SVM dataset: 765
# Number of data in regression dataset: 765
# Processing image 1807
# Number of data in SVM dataset: 807
# Number of data in regression dataset: 807
# Processing image 1808
# Number of data in SVM dataset: 935
# Number of data in regression dataset: 935
# Processing image 1809
# Number of data in SVM dataset: 963
# Number of data in regression dataset: 963
# Processing image 1810
# Number of data in SVM dataset: 1139
# Number of data in regression dataset: 1139
# Processing image 1811
# Number of data in SVM dataset: 1346
# Number of data in regression dataset: 1346
# Processing image 1812
# Number of data in SVM dataset: 1400
# Number of data in regression dataset: 1400
# Processing image 1813
# Number of data in SVM dataset: 1723
# Number of data in regression dataset: 1723
# Processing image 1814
# Number of data in SVM dataset: 1751
# Number of data in regression dataset: 1751
# Processing image 1815
# Number of data in SVM dataset: 1841
# Number of data in regression dataset: 1841
# Processing image 1816
# Number of data in SVM dataset: 2073
# Number of data in regression dataset: 2073
# Processing image 1817
# Number of data in SVM dataset: 2130
# Number of data in regression dataset: 2130
# Processing image 1818
# Number of data in SVM dataset: 2365
# Number of data in regression dataset: 2365
# Processing image 1819
# Number of data in SVM dataset: 2369
# Number of data in regression dataset: 2369
# Processing image 1820
# Number of data in SVM dataset: 2467
# Number of data in regression dataset: 2467
# Processing image 1821
# Number of data in SVM dataset: 2489
# Number of data in regression dataset: 2489
# Processing image 1822
# Number of data in SVM dataset: 2728
# Number of data in regression dataset: 2728
# Processing image 1823
# Number of data in SVM dataset: 2742
# Number of data in regression dataset: 2742
# Processing image 1824
# Number of data in SVM dataset: 3066
# Number of data in regression dataset: 3066
# Processing image 1825
# Number of data in SVM dataset: 3403
# Number of data in regression dataset: 3403
# Processing image 1826
# Number of data in SVM dataset: 3538
# Number of data in regression dataset: 3538
# Processing image 1827
# Number of data in SVM dataset: 3713
# Number of data in regression dataset: 3713
# Processing image 1828
# Number of data in SVM dataset: 3878
# Number of data in regression dataset: 3878
# Processing image 1829
# Number of data in SVM dataset: 4115
# Number of data in regression dataset: 4115
# Processing image 1830
# Number of data in SVM dataset: 4428
# Number of data in regression dataset: 4428
# Processing image 1831
# Number of data in SVM dataset: 4499
# Number of data in regression dataset: 4499
# Processing image 1832
# Number of data in SVM dataset: 4669
# Number of data in regression dataset: 4669
# Processing image 1833
# Number of data in SVM dataset: 4700
# Number of data in regression dataset: 4700
# Processing image 1834
# Number of data in SVM dataset: 4973
# Number of data in regression dataset: 4973
# Processing image 1835
# Number of data in SVM dataset: 5253
# Number of data in regression dataset: 5253
# Processing image 1836
# Number of data in SVM dataset: 5268
# Number of data in regression dataset: 5268
# Processing image 1837
# Number of data in SVM dataset: 5423
# Number of data in regression dataset: 5423
# Processing image 1838
# Number of data in SVM dataset: 5631
# Number of data in regression dataset: 5631
# Processing image 1839
# Number of data in SVM dataset: 5856
# Number of data in regression dataset: 5856
# Processing image 1840
# Number of data in SVM dataset: 5941
# Number of data in regression dataset: 5941
# Processing image 1841
# Number of data in SVM dataset: 6170
# Number of data in regression dataset: 6170
# Processing image 1842
# Number of data in SVM dataset: 6488
# Number of data in regression dataset: 6488
# Processing image 1843
# Number of data in SVM dataset: 6569
# Number of data in regression dataset: 6569
# Processing image 1844
# Number of data in SVM dataset: 6575
# Number of data in regression dataset: 6575
# Processing image 1845
# Number of data in SVM dataset: 6622
# Number of data in regression dataset: 6622
# Processing image 1846
# Number of data in SVM dataset: 6944
# Number of data in regression dataset: 6944
# Processing image 1847
# Number of data in SVM dataset: 7297
# Number of data in regression dataset: 7297
# Processing image 1848
# Number of data in SVM dataset: 7479
# Number of data in regression dataset: 7479
# Processing image 1849
# Number of data in SVM dataset: 7659
# Number of data in regression dataset: 7659
# Processing image 1850
# Number of data in SVM dataset: 7736
# Number of data in regression dataset: 7736
# Processing image 1851
# Number of data in SVM dataset: 7786
# Number of data in regression dataset: 7786
# Processing image 1852
# Number of data in SVM dataset: 8013
# Number of data in regression dataset: 8013
# Processing image 1853
# Number of data in SVM dataset: 8091
# Number of data in regression dataset: 8091
# Processing image 1854
# Number of data in SVM dataset: 8115
# Number of data in regression dataset: 8115
# Processing image 1855
# Number of data in SVM dataset: 8153
# Number of data in regression dataset: 8153
# Processing image 1856
# Number of data in SVM dataset: 8329
# Number of data in regression dataset: 8329
# Processing image 1857
# Number of data in SVM dataset: 8515
# Number of data in regression dataset: 8515
# Processing image 1858
# Number of data in SVM dataset: 8574
# Number of data in regression dataset: 8574
# Processing image 1859
# Number of data in SVM dataset: 8670
# Number of data in regression dataset: 8670
# Processing image 1860
# Number of data in SVM dataset: 8779
# Number of data in regression dataset: 8779
# Processing image 1861
# Number of data in SVM dataset: 8889
# Number of data in regression dataset: 8889
# Processing image 1862
# Number of data in SVM dataset: 8977
# Number of data in regression dataset: 8977
# Processing image 1863
# Number of data in SVM dataset: 9088
# Number of data in regression dataset: 9088
# Processing image 1864
# Number of data in SVM dataset: 9259
# Number of data in regression dataset: 9259
# Processing image 1865
# Number of data in SVM dataset: 9408
# Number of data in regression dataset: 9408
# Processing image 1866
# Number of data in SVM dataset: 9483
# Number of data in regression dataset: 9483
# Processing image 1867
# Number of data in SVM dataset: 9558
# Number of data in regression dataset: 9558
# Processing image 1868
# Number of data in SVM dataset: 9559
# Number of data in regression dataset: 9559
# Processing image 1869
# Number of data in SVM dataset: 9659
# Number of data in regression dataset: 9659
# Processing image 1870
# Number of data in SVM dataset: 9765
# Number of data in regression dataset: 9765
# Processing image 1871
# Number of data in SVM dataset: 9808
# Number of data in regression dataset: 9808
# Processing image 1872
# Number of data in SVM dataset: 10133
# Number of data in regression dataset: 10133
# Processing image 1873
# Number of data in SVM dataset: 10365
# Number of data in regression dataset: 10365
# Processing image 1874
# Number of data in SVM dataset: 10623
# Number of data in regression dataset: 10623
# Processing image 1875
# Number of data in SVM dataset: 10683
# Number of data in regression dataset: 10683
# Processing image 1876
# Number of data in SVM dataset: 10908
# Number of data in regression dataset: 10908
# Processing image 1877
# Number of data in SVM dataset: 11001
# Number of data in regression dataset: 11001
# Processing image 1878
# Number of data in SVM dataset: 11162
# Number of data in regression dataset: 11162
# Processing image 1879
# Number of data in SVM dataset: 11418
# Number of data in regression dataset: 11418
# Processing image 1880
# Number of data in SVM dataset: 11481
# Number of data in regression dataset: 11481
# Processing image 1881
# Number of data in SVM dataset: 11669
# Number of data in regression dataset: 11669
# Processing image 1882
# Number of data in SVM dataset: 11787
# Number of data in regression dataset: 11787
# Processing image 1883
# Number of data in SVM dataset: 11837
# Number of data in regression dataset: 11837
# Processing image 1884
# Number of data in SVM dataset: 12059
# Number of data in regression dataset: 12059
# Processing image 1885
# Number of data in SVM dataset: 12059
# Number of data in regression dataset: 12059
# Processing image 1886
# Number of data in SVM dataset: 12205
# Number of data in regression dataset: 12205
# Processing image 1887
# Number of data in SVM dataset: 12319
# Number of data in regression dataset: 12319
# Processing image 1888
# Number of data in SVM dataset: 12322
# Number of data in regression dataset: 12322
# Processing image 1889
# Number of data in SVM dataset: 12506
# Number of data in regression dataset: 12506
# Processing image 1890
# Number of data in SVM dataset: 12594
# Number of data in regression dataset: 12594
# Processing image 1891
# Number of data in SVM dataset: 12943
# Number of data in regression dataset: 12943
# Processing image 1892
# Number of data in SVM dataset: 13060
# Number of data in regression dataset: 13060
# Processing image 1893
# Number of data in SVM dataset: 13352
# Number of data in regression dataset: 13352
# Processing image 1894
# Number of data in SVM dataset: 13444
# Number of data in regression dataset: 13444
# Processing image 1895
# Number of data in SVM dataset: 13579
# Number of data in regression dataset: 13579
# Processing image 1896
# Number of data in SVM dataset: 13691
# Number of data in regression dataset: 13691
# Processing image 1897
# Number of data in SVM dataset: 13734
# Number of data in regression dataset: 13734
# Processing image 1898
# Number of data in SVM dataset: 13752
# Number of data in regression dataset: 13752
# Processing image 1899
# Number of data in SVM dataset: 13784
# Number of data in regression dataset: 13784
# Processing image 1900
# Number of data in SVM dataset: 13958
# Number of data in regression dataset: 13958
# Processing image 1901
# Number of data in SVM dataset: 13979
# Number of data in regression dataset: 13979
# Processing image 1902
# Number of data in SVM dataset: 14165
# Number of data in regression dataset: 14165
# Processing image 1903
# Number of data in SVM dataset: 14257
# Number of data in regression dataset: 14257
# Processing image 1904
# Number of data in SVM dataset: 14281
# Number of data in regression dataset: 14281
# Processing image 1905
# Number of data in SVM dataset: 14468
# Number of data in regression dataset: 14468
# Processing image 1906
# Number of data in SVM dataset: 14552
# Number of data in regression dataset: 14552
# Processing image 1907
# Number of data in SVM dataset: 14598
# Number of data in regression dataset: 14598
# Processing image 1908
# Number of data in SVM dataset: 14809
# Number of data in regression dataset: 14809
# Processing image 1909
# Number of data in SVM dataset: 14872
# Number of data in regression dataset: 14872
# Processing image 1910
# Number of data in SVM dataset: 14998
# Number of data in regression dataset: 14998
# Processing image 1911
# Number of data in SVM dataset: 15179
# Number of data in regression dataset: 15179
# Processing image 1912
# Number of data in SVM dataset: 15429
# Number of data in regression dataset: 15429
# Processing image 1913
# Number of data in SVM dataset: 15723
# Number of data in regression dataset: 15723
# Processing image 1914
# Number of data in SVM dataset: 16062
# Number of data in regression dataset: 16062
# Processing image 1915
# Number of data in SVM dataset: 16071
# Number of data in regression dataset: 16071
# Processing image 1916
# Number of data in SVM dataset: 16349
# Number of data in regression dataset: 16349
# Processing image 1917
# Number of data in SVM dataset: 16519
# Number of data in regression dataset: 16519
# Processing image 1918
# Number of data in SVM dataset: 16561
# Number of data in regression dataset: 16561
# Processing image 1919
# Number of data in SVM dataset: 16601
# Number of data in regression dataset: 16601
# Processing image 1920
# Number of data in SVM dataset: 16693
# Number of data in regression dataset: 16693
# Processing image 1921
# Number of data in SVM dataset: 16794
# Number of data in regression dataset: 16794
# Processing image 1922
# Number of data in SVM dataset: 16827
# Number of data in regression dataset: 16827
# Processing image 1923
# Number of data in SVM dataset: 16928
# Number of data in regression dataset: 16928
# Processing image 1924
# Number of data in SVM dataset: 17022
# Number of data in regression dataset: 17022
# Processing image 1925
# Number of data in SVM dataset: 17103
# Number of data in regression dataset: 17103
# Processing image 1926
# Number of data in SVM dataset: 17309
# Number of data in regression dataset: 17309
# Processing image 1927
# Number of data in SVM dataset: 17491
# Number of data in regression dataset: 17491
# Processing image 1928
# Number of data in SVM dataset: 17540
# Number of data in regression dataset: 17540
# Processing image 1929
# Number of data in SVM dataset: 17681
# Number of data in regression dataset: 17681
# Processing image 1930
# Number of data in SVM dataset: 17807
# Number of data in regression dataset: 17807
# Processing image 1931
# Number of data in SVM dataset: 18079
# Number of data in regression dataset: 18079
# Processing image 1932
# Number of data in SVM dataset: 18161
# Number of data in regression dataset: 18161
# Processing image 1933
# Number of data in SVM dataset: 18225
# Number of data in regression dataset: 18225
# Processing image 1934
# Number of data in SVM dataset: 18271
# Number of data in regression dataset: 18271
# Processing image 1935
# Number of data in SVM dataset: 18541
# Number of data in regression dataset: 18541
# Processing image 1936
# Number of data in SVM dataset: 18580
# Number of data in regression dataset: 18580
# Processing image 1937
# Number of data in SVM dataset: 18828
# Number of data in regression dataset: 18828
# Processing image 1938
# Number of data in SVM dataset: 19042
# Number of data in regression dataset: 19042
# Processing image 1939
# Number of data in SVM dataset: 19042
# Number of data in regression dataset: 19042
# Processing image 1940
# Number of data in SVM dataset: 19141
# Number of data in regression dataset: 19141
# Processing image 1941
# Number of data in SVM dataset: 19478
# Number of data in regression dataset: 19478
# Processing image 1942
# Number of data in SVM dataset: 19636
# Number of data in regression dataset: 19636
# Processing image 1943
# Number of data in SVM dataset: 19649
# Number of data in regression dataset: 19649
# Processing image 1944
# Number of data in SVM dataset: 19744
# Number of data in regression dataset: 19744
# Processing image 1945
# Number of data in SVM dataset: 20003
# Number of data in regression dataset: 20003
# Processing image 1946
# Number of data in SVM dataset: 20213
# Number of data in regression dataset: 20213
# Processing image 1947
# Number of data in SVM dataset: 20287
# Number of data in regression dataset: 20287
# Processing image 1948
# Number of data in SVM dataset: 20554
# Number of data in regression dataset: 20554
# Processing image 1949
# Number of data in SVM dataset: 20745
# Number of data in regression dataset: 20745
# Processing image 1950
# Number of data in SVM dataset: 20898
# Number of data in regression dataset: 20898
# Processing image 1951
# Number of data in SVM dataset: 21210
# Number of data in regression dataset: 21210
# Processing image 1952
# Number of data in SVM dataset: 21256
# Number of data in regression dataset: 21256
# Processing image 1953
# Number of data in SVM dataset: 21328
# Number of data in regression dataset: 21328
# Processing image 1954
# Number of data in SVM dataset: 21649
# Number of data in regression dataset: 21649
# Processing image 1955
# Number of data in SVM dataset: 21854
# Number of data in regression dataset: 21854
# Processing image 1956
# Number of data in SVM dataset: 21880
# Number of data in regression dataset: 21880
# Processing image 1957
# Number of data in SVM dataset: 22207
# Number of data in regression dataset: 22207
# Processing image 1958
# Number of data in SVM dataset: 22372
# Number of data in regression dataset: 22372
# Processing image 1959
# Number of data in SVM dataset: 22602
# Number of data in regression dataset: 22602
# Processing image 1960
# Number of data in SVM dataset: 22679
# Number of data in regression dataset: 22679
# Processing image 1961
# Number of data in SVM dataset: 22793
# Number of data in regression dataset: 22793
# Processing image 1962
# Number of data in SVM dataset: 22956
# Number of data in regression dataset: 22956
# Processing image 1963
# Number of data in SVM dataset: 23110
# Number of data in regression dataset: 23110
# Processing image 1964
# Number of data in SVM dataset: 23224
# Number of data in regression dataset: 23224
# Processing image 1965
# Number of data in SVM dataset: 23292
# Number of data in regression dataset: 23292
# Processing image 1966
# Number of data in SVM dataset: 23414
# Number of data in regression dataset: 23414
# Processing image 1967
# Number of data in SVM dataset: 23588
# Number of data in regression dataset: 23588
# Processing image 1968
# Number of data in SVM dataset: 23704
# Number of data in regression dataset: 23704
# Processing image 1969
# Number of data in SVM dataset: 23707
# Number of data in regression dataset: 23707
# Processing image 1970
# Number of data in SVM dataset: 23879
# Number of data in regression dataset: 23879
# Processing image 1971
# Number of data in SVM dataset: 23998
# Number of data in regression dataset: 23998
# Processing image 1972
# Number of data in SVM dataset: 24023
# Number of data in regression dataset: 24023
# Processing image 1973
# Number of data in SVM dataset: 24168
# Number of data in regression dataset: 24168
# Processing image 1974
# Number of data in SVM dataset: 24248
# Number of data in regression dataset: 24248
# Processing image 1975
# Number of data in SVM dataset: 24438
# Number of data in regression dataset: 24438
# Processing image 1976
# Number of data in SVM dataset: 24470
# Number of data in regression dataset: 24470
# Processing image 1977
# Number of data in SVM dataset: 24746
# Number of data in regression dataset: 24746
# Processing image 1978
# Number of data in SVM dataset: 24799
# Number of data in regression dataset: 24799
# Processing image 1979
# Number of data in SVM dataset: 24907
# Number of data in regression dataset: 24907
# Processing image 1980
# Number of data in SVM dataset: 24910
# Number of data in regression dataset: 24910
# Processing image 1981
# Number of data in SVM dataset: 25089
# Number of data in regression dataset: 25089
# Processing image 1982
# Number of data in SVM dataset: 25091
# Number of data in regression dataset: 25091
# Processing image 1983
# Number of data in SVM dataset: 25091
# Number of data in regression dataset: 25091
# Processing image 1984
# Number of data in SVM dataset: 25160
# Number of data in regression dataset: 25160
# Processing image 1985
# Number of data in SVM dataset: 25354
# Number of data in regression dataset: 25354
# Processing image 1986
# Number of data in SVM dataset: 25486
# Number of data in regression dataset: 25486
# Processing image 1987
# Number of data in SVM dataset: 25570
# Number of data in regression dataset: 25570
# Processing image 1988
# Number of data in SVM dataset: 25730
# Number of data in regression dataset: 25730
# Processing image 1989
# Number of data in SVM dataset: 25831
# Number of data in regression dataset: 25831
# Processing image 1990
# Number of data in SVM dataset: 25950
# Number of data in regression dataset: 25950
# Processing image 1991
# Number of data in SVM dataset: 26269
# Number of data in regression dataset: 26269
# Processing image 1992
# Number of data in SVM dataset: 26409
# Number of data in regression dataset: 26409
# Processing image 1993
# Number of data in SVM dataset: 26508
# Number of data in regression dataset: 26508
# Processing image 1994
# Number of data in SVM dataset: 26577
# Number of data in regression dataset: 26577
# Processing image 1995
# Number of data in SVM dataset: 26793
# Number of data in regression dataset: 26793
# Processing image 1996
# Number of data in SVM dataset: 26824
# Number of data in regression dataset: 26824
# Processing image 1997
# Number of data in SVM dataset: 26848
# Number of data in regression dataset: 26848
# Processing image 1998
# Number of data in SVM dataset: 26866
# Number of data in regression dataset: 26866
# Processing image 1999
# Number of data in SVM dataset: 26974
# Number of data in regression dataset: 26974
# Processing image 2000
# Number of data in SVM dataset: 27051
# Number of data in regression dataset: 27051
# Processing image 2001
# Number of data in SVM dataset: 27216
# Number of data in regression dataset: 27216
# Processing image 2002
# Number of data in SVM dataset: 27250
# Number of data in regression dataset: 27250
# Processing image 2003
# Number of data in SVM dataset: 27253
# Number of data in regression dataset: 27253
# Processing image 2004
# Number of data in SVM dataset: 27468
# Number of data in regression dataset: 27468
# Processing image 2005
# Number of data in SVM dataset: 27706
# Number of data in regression dataset: 27706
# Processing image 2006
# Number of data in SVM dataset: 27719
# Number of data in regression dataset: 27719
# Processing image 2007
# Number of data in SVM dataset: 27803
# Number of data in regression dataset: 27803
# Processing image 2008
# Number of data in SVM dataset: 27808
# Number of data in regression dataset: 27808
# Processing image 2009
# Number of data in SVM dataset: 27903
# Number of data in regression dataset: 27903
# Processing image 2010
# Number of data in SVM dataset: 27948
# Number of data in regression dataset: 27948
# Processing image 2011
# Number of data in SVM dataset: 28194
# Number of data in regression dataset: 28194
# Processing image 2012
# Number of data in SVM dataset: 28421
# Number of data in regression dataset: 28421
# Processing image 2013
# Number of data in SVM dataset: 28478
# Number of data in regression dataset: 28478
# Processing image 2014
# Number of data in SVM dataset: 28603
# Number of data in regression dataset: 28603
# Processing image 2015
# Number of data in SVM dataset: 28680
# Number of data in regression dataset: 28680
# Processing image 2016
# Number of data in SVM dataset: 28847
# Number of data in regression dataset: 28847
# Processing image 2017
# Number of data in SVM dataset: 29282
# Number of data in regression dataset: 29282
# Processing image 2018
# Number of data in SVM dataset: 29415
# Number of data in regression dataset: 29415
# Processing image 2019
# Number of data in SVM dataset: 29605
# Number of data in regression dataset: 29605
# Processing image 2020
# Number of data in SVM dataset: 29840
# Number of data in regression dataset: 29840
# Processing image 2021
# Number of data in SVM dataset: 30004
# Number of data in regression dataset: 30004
# Processing image 2022
# Number of data in SVM dataset: 30153
# Number of data in regression dataset: 30153
# Processing image 2023
# Number of data in SVM dataset: 30153
# Number of data in regression dataset: 30153
# Processing image 2024
# Number of data in SVM dataset: 30323
# Number of data in regression dataset: 30323
# Processing image 2025
# Number of data in SVM dataset: 30575
# Number of data in regression dataset: 30575
# Processing image 2026
# Number of data in SVM dataset: 31008
# Number of data in regression dataset: 31008
# Processing image 2027
# Number of data in SVM dataset: 31375
# Number of data in regression dataset: 31375
# Processing image 2028
# Number of data in SVM dataset: 31478
# Number of data in regression dataset: 31478
# Processing image 2029
# Number of data in SVM dataset: 31586
# Number of data in regression dataset: 31586
# Processing image 2030
# Number of data in SVM dataset: 31700
# Number of data in regression dataset: 31700
# Processing image 2031
# Number of data in SVM dataset: 31843
# Number of data in regression dataset: 31843
# Processing image 2032
# Number of data in SVM dataset: 31855
# Number of data in regression dataset: 31855
# Processing image 2033
# Number of data in SVM dataset: 31991
# Number of data in regression dataset: 31991
# Processing image 2034
# Number of data in SVM dataset: 32145
# Number of data in regression dataset: 32145
# Processing image 2035
# Number of data in SVM dataset: 32145
# Number of data in regression dataset: 32145
# Processing image 2036
# Number of data in SVM dataset: 32183
# Number of data in regression dataset: 32183
# Processing image 2037
# Number of data in SVM dataset: 32317
# Number of data in regression dataset: 32317
# Processing image 2038
# Number of data in SVM dataset: 32332
# Number of data in regression dataset: 32332
# Processing image 2039
# Number of data in SVM dataset: 32560
# Number of data in regression dataset: 32560
# Processing image 2040
# Number of data in SVM dataset: 32807
# Number of data in regression dataset: 32807
# Processing image 2041
# Number of data in SVM dataset: 32961
# Number of data in regression dataset: 32961
# Processing image 2042
# Number of data in SVM dataset: 32977
# Number of data in regression dataset: 32977
# Processing image 2043
# Number of data in SVM dataset: 33153
# Number of data in regression dataset: 33153
# Processing image 2044
# Number of data in SVM dataset: 33452
# Number of data in regression dataset: 33452
# Processing image 2045
# Number of data in SVM dataset: 33467
# Number of data in regression dataset: 33467
# Processing image 2046
# Number of data in SVM dataset: 33658
# Number of data in regression dataset: 33658
# Processing image 2047
# Number of data in SVM dataset: 33752
# Number of data in regression dataset: 33752
# Processing image 2048
# Number of data in SVM dataset: 34131
# Number of data in regression dataset: 34131
# Processing image 2049
# Number of data in SVM dataset: 34442
# Number of data in regression dataset: 34442
# Processing image 2050
# Number of data in SVM dataset: 34447
# Number of data in regression dataset: 34447
# Processing image 2051
# Number of data in SVM dataset: 34633
# Number of data in regression dataset: 34633
# Processing image 2052
# Number of data in SVM dataset: 34884
# Number of data in regression dataset: 34884
# Processing image 2053
# Number of data in SVM dataset: 35048
# Number of data in regression dataset: 35048
# Processing image 2054
# Number of data in SVM dataset: 35161
# Number of data in regression dataset: 35161
# Processing image 2055
# Number of data in SVM dataset: 35306
# Number of data in regression dataset: 35306
# Processing image 2056
# Number of data in SVM dataset: 35326
# Number of data in regression dataset: 35326
# Processing image 2057
# Number of data in SVM dataset: 35435
# Number of data in regression dataset: 35435
# Processing image 2058
# Number of data in SVM dataset: 35445
# Number of data in regression dataset: 35445
# Processing image 2059
# Number of data in SVM dataset: 35638
# Number of data in regression dataset: 35638
# Processing image 2060
# Number of data in SVM dataset: 35677
# Number of data in regression dataset: 35677
# Processing image 2061
# Number of data in SVM dataset: 35858
# Number of data in regression dataset: 35858
# Processing image 2062
# Number of data in SVM dataset: 36157
# Number of data in regression dataset: 36157
# Processing image 2063
# Number of data in SVM dataset: 36405
# Number of data in regression dataset: 36405
# Processing image 2064
# Number of data in SVM dataset: 36572
# Number of data in regression dataset: 36572
# Processing image 2065
# Number of data in SVM dataset: 36885
# Number of data in regression dataset: 36885
# Processing image 2066
# Number of data in SVM dataset: 36941
# Number of data in regression dataset: 36941
# Processing image 2067
# Number of data in SVM dataset: 37305
# Number of data in regression dataset: 37305
# Processing image 2068
# Number of data in SVM dataset: 37411
# Number of data in regression dataset: 37411
# Processing image 2069
# Number of data in SVM dataset: 37916
# Number of data in regression dataset: 37916
# Processing image 2070
# Number of data in SVM dataset: 38064
# Number of data in regression dataset: 38064
# Processing image 2071
# Number of data in SVM dataset: 38068
# Number of data in regression dataset: 38068
# Processing image 2072
# Number of data in SVM dataset: 38215
# Number of data in regression dataset: 38215
# Processing image 2073
# Number of data in SVM dataset: 38415
# Number of data in regression dataset: 38415
# Processing image 2074
# Number of data in SVM dataset: 38545
# Number of data in regression dataset: 38545
# Processing image 2075
# Number of data in SVM dataset: 38754
# Number of data in regression dataset: 38754
# Processing image 2076
# Number of data in SVM dataset: 38804
# Number of data in regression dataset: 38804
# Processing image 2077
# Number of data in SVM dataset: 38988
# Number of data in regression dataset: 38988
# Processing image 2078
# Number of data in SVM dataset: 38988
# Number of data in regression dataset: 38988
# Processing image 2079
# Number of data in SVM dataset: 39136
# Number of data in regression dataset: 39136
# Processing image 2080
# Number of data in SVM dataset: 39464
# Number of data in regression dataset: 39464
# Processing image 2081
# Number of data in SVM dataset: 39621
# Number of data in regression dataset: 39621
# Processing image 2082
# Number of data in SVM dataset: 39963
# Number of data in regression dataset: 39963
# Processing image 2083
# Number of data in SVM dataset: 40133
# Number of data in regression dataset: 40133
# Processing image 2084
# Number of data in SVM dataset: 40234
# Number of data in regression dataset: 40234
# Processing image 2085
# Number of data in SVM dataset: 40258
# Number of data in regression dataset: 40258
# Processing image 2086
# Number of data in SVM dataset: 40265
# Number of data in regression dataset: 40265
# Processing image 2087
# Number of data in SVM dataset: 40517
# Number of data in regression dataset: 40517
# Processing image 2088
# Number of data in SVM dataset: 40594
# Number of data in regression dataset: 40594
# Processing image 2089
# Number of data in SVM dataset: 40816
# Number of data in regression dataset: 40816
# Processing image 2090
# Number of data in SVM dataset: 41076
# Number of data in regression dataset: 41076
# Processing image 2091
# Number of data in SVM dataset: 41142
# Number of data in regression dataset: 41142
# Processing image 2092
# Number of data in SVM dataset: 41315
# Number of data in regression dataset: 41315
# Processing image 2093
# Number of data in SVM dataset: 41506
# Number of data in regression dataset: 41506
# Processing image 2094
# Number of data in SVM dataset: 41803
# Number of data in regression dataset: 41803
# Processing image 2095
# Number of data in SVM dataset: 42036
# Number of data in regression dataset: 42036
# Processing image 2096
# Number of data in SVM dataset: 42168
# Number of data in regression dataset: 42168
# Processing image 2097
# Number of data in SVM dataset: 42241
# Number of data in regression dataset: 42241
# Processing image 2098
# Number of data in SVM dataset: 42275
# Number of data in regression dataset: 42275
# Processing image 2099
# Number of data in SVM dataset: 42289
# Number of data in regression dataset: 42289
# Processing image 2100
# Number of data in SVM dataset: 42341
# Number of data in regression dataset: 42341
# Processing image 2101
# Number of data in SVM dataset: 42350
# Number of data in regression dataset: 42350
# Processing image 2102
# Number of data in SVM dataset: 42450
# Number of data in regression dataset: 42450
# Processing image 2103
# Number of data in SVM dataset: 42472
# Number of data in regression dataset: 42472
# Processing image 2104
# Number of data in SVM dataset: 42607
# Number of data in regression dataset: 42607
# Processing image 2105
# Number of data in SVM dataset: 42820
# Number of data in regression dataset: 42820
# Processing image 2106
# Number of data in SVM dataset: 43123
# Number of data in regression dataset: 43123
# Processing image 2107
# Number of data in SVM dataset: 43342
# Number of data in regression dataset: 43342
# Processing image 2108
# Number of data in SVM dataset: 43583
# Number of data in regression dataset: 43583
# Processing image 2109
# Number of data in SVM dataset: 43832
# Number of data in regression dataset: 43832
# Processing image 2110
# Number of data in SVM dataset: 43918
# Number of data in regression dataset: 43918
# Processing image 2111
# Number of data in SVM dataset: 44010
# Number of data in regression dataset: 44010
# Processing image 2112
# Number of data in SVM dataset: 44204
# Number of data in regression dataset: 44204
# Processing image 2113
# Number of data in SVM dataset: 44430
# Number of data in regression dataset: 44430
# Processing image 2114
# Number of data in SVM dataset: 44758
# Number of data in regression dataset: 44758
# Processing image 2115
# Number of data in SVM dataset: 44842
# Number of data in regression dataset: 44842
# Processing image 2116
# Number of data in SVM dataset: 44976
# Number of data in regression dataset: 44976
# Processing image 2117
# Number of data in SVM dataset: 45039
# Number of data in regression dataset: 45039
# Processing image 2118
# Number of data in SVM dataset: 45184
# Number of data in regression dataset: 45184
# Processing image 2119
# Number of data in SVM dataset: 45289
# Number of data in regression dataset: 45289
# Processing image 2120
# Number of data in SVM dataset: 45339
# Number of data in regression dataset: 45339
# Processing image 2121
# Number of data in SVM dataset: 45427
# Number of data in regression dataset: 45427
# Processing image 2122
# Number of data in SVM dataset: 45587
# Number of data in regression dataset: 45587
# Processing image 2123
# Number of data in SVM dataset: 45761
# Number of data in regression dataset: 45761
# Processing image 2124
# Number of data in SVM dataset: 45951
# Number of data in regression dataset: 45951
# Processing image 2125
# Number of data in SVM dataset: 46287
# Number of data in regression dataset: 46287
# Processing image 2126
# Number of data in SVM dataset: 46325
# Number of data in regression dataset: 46325
# Processing image 2127
# Number of data in SVM dataset: 46586
# Number of data in regression dataset: 46586
# Processing image 2128
# Number of data in SVM dataset: 46914
# Number of data in regression dataset: 46914
# Processing image 2129
# Number of data in SVM dataset: 47107
# Number of data in regression dataset: 47107
# Processing image 2130
# Number of data in SVM dataset: 47207
# Number of data in regression dataset: 47207
# Processing image 2131
# Number of data in SVM dataset: 47228
# Number of data in regression dataset: 47228
# Processing image 2132
# Number of data in SVM dataset: 47346
# Number of data in regression dataset: 47346
# Processing image 2133
# Number of data in SVM dataset: 47414
# Number of data in regression dataset: 47414
# Processing image 2134
# Number of data in SVM dataset: 47533
# Number of data in regression dataset: 47533
# Processing image 2135
# Number of data in SVM dataset: 47557
# Number of data in regression dataset: 47557
# Processing image 2136
# Number of data in SVM dataset: 47807
# Number of data in regression dataset: 47807
# Processing image 2137
# Number of data in SVM dataset: 47870
# Number of data in regression dataset: 47870
# Processing image 2138
# Number of data in SVM dataset: 48052
# Number of data in regression dataset: 48052
# Processing image 2139
# Number of data in SVM dataset: 48119
# Number of data in regression dataset: 48119
# Processing image 2140
# Number of data in SVM dataset: 48306
# Number of data in regression dataset: 48306
# Processing image 2141
# Number of data in SVM dataset: 48425
# Number of data in regression dataset: 48425
# Processing image 2142
# Number of data in SVM dataset: 48490
# Number of data in regression dataset: 48490
# Processing image 2143
# Number of data in SVM dataset: 48665
# Number of data in regression dataset: 48665
# Processing image 2144
# Number of data in SVM dataset: 48866
# Number of data in regression dataset: 48866
# Processing image 2145
# Number of data in SVM dataset: 48961
# Number of data in regression dataset: 48961
# Processing image 2146
# Number of data in SVM dataset: 49039
# Number of data in regression dataset: 49039
# Processing image 2147
# Number of data in SVM dataset: 49364
# Number of data in regression dataset: 49364
# Processing image 2148
# Number of data in SVM dataset: 49439
# Number of data in regression dataset: 49439
# Processing image 2149
# Number of data in SVM dataset: 49663
# Number of data in regression dataset: 49663
# Processing image 2150
# Number of data in SVM dataset: 49820
# Number of data in regression dataset: 49820
# Processing image 2151
# Number of data in SVM dataset: 49902
# Number of data in regression dataset: 49902
# Processing image 2152
# Number of data in SVM dataset: 50011
# Number of data in regression dataset: 50011
# Processing image 2153
# Number of data in SVM dataset: 50068
# Number of data in regression dataset: 50068
# Processing image 2154
# Number of data in SVM dataset: 50288
# Number of data in regression dataset: 50288
# Processing image 2155
# Number of data in SVM dataset: 50291
# Number of data in regression dataset: 50291
# Processing image 2156
# Number of data in SVM dataset: 50461
# Number of data in regression dataset: 50461
# Processing image 2157
# Number of data in SVM dataset: 50655
# Number of data in regression dataset: 50655
# Processing image 2158
# Number of data in SVM dataset: 50861
# Number of data in regression dataset: 50861
# Processing image 2159
# Number of data in SVM dataset: 51042
# Number of data in regression dataset: 51042
# Processing image 2160
# Number of data in SVM dataset: 51217
# Number of data in regression dataset: 51217
# Processing image 2161
# Number of data in SVM dataset: 51262
# Number of data in regression dataset: 51262
# Processing image 2162
# Number of data in SVM dataset: 51453
# Number of data in regression dataset: 51453
# Processing image 2163
# Number of data in SVM dataset: 51465
# Number of data in regression dataset: 51465
# Processing image 2164
# Number of data in SVM dataset: 51602
# Number of data in regression dataset: 51602
# Processing image 2165
# Number of data in SVM dataset: 51703
# Number of data in regression dataset: 51703
# Processing image 2166
# Number of data in SVM dataset: 51741
# Number of data in regression dataset: 51741
# Processing image 2167
# Number of data in SVM dataset: 51809
# Number of data in regression dataset: 51809
# Processing image 2168
# Number of data in SVM dataset: 51921
# Number of data in regression dataset: 51921
# Processing image 2169
# Number of data in SVM dataset: 52026
# Number of data in regression dataset: 52026
# Processing image 2170
# Number of data in SVM dataset: 52131
# Number of data in regression dataset: 52131
# Processing image 2171
# Number of data in SVM dataset: 52252
# Number of data in regression dataset: 52252
# Processing image 2172
# Number of data in SVM dataset: 52502
# Number of data in regression dataset: 52502
# Processing image 2173
# Number of data in SVM dataset: 52530
# Number of data in regression dataset: 52530
# Processing image 2174
# Number of data in SVM dataset: 52673
# Number of data in regression dataset: 52673
# Processing image 2175
# Number of data in SVM dataset: 52952
# Number of data in regression dataset: 52952
# Processing image 2176
# Number of data in SVM dataset: 53160
# Number of data in regression dataset: 53160
# Processing image 2177
# Number of data in SVM dataset: 53413
# Number of data in regression dataset: 53413
# Processing image 2178
# Number of data in SVM dataset: 53482
# Number of data in regression dataset: 53482
# Processing image 2179
# Number of data in SVM dataset: 53565
# Number of data in regression dataset: 53565
# Processing image 2180
# Number of data in SVM dataset: 53700
# Number of data in regression dataset: 53700
# Processing image 2181
# Number of data in SVM dataset: 53831
# Number of data in regression dataset: 53831
# Processing image 2182
# Number of data in SVM dataset: 54009
# Number of data in regression dataset: 54009
# Processing image 2183
# Number of data in SVM dataset: 54036
# Number of data in regression dataset: 54036
# Processing image 2184
# Number of data in SVM dataset: 54203
# Number of data in regression dataset: 54203
# Processing image 2185
# Number of data in SVM dataset: 54235
# Number of data in regression dataset: 54235
# Processing image 2186
# Number of data in SVM dataset: 54310
# Number of data in regression dataset: 54310
# Processing image 2187
# Number of data in SVM dataset: 54427
# Number of data in regression dataset: 54427
# Processing image 2188
# Number of data in SVM dataset: 54519
# Number of data in regression dataset: 54519
# Processing image 2189
# Number of data in SVM dataset: 54584
# Number of data in regression dataset: 54584
# Processing image 2190
# Number of data in SVM dataset: 54833
# Number of data in regression dataset: 54833
# Processing image 2191
# Number of data in SVM dataset: 54997
# Number of data in regression dataset: 54997
# Processing image 2192
# Number of data in SVM dataset: 55362
# Number of data in regression dataset: 55362
# Processing image 2193
# Number of data in SVM dataset: 55538
# Number of data in regression dataset: 55538
# Processing image 2194
# Number of data in SVM dataset: 55756
# Number of data in regression dataset: 55756
# Processing image 2195
# Number of data in SVM dataset: 55946
# Number of data in regression dataset: 55946
# Processing image 2196
# Number of data in SVM dataset: 56206
# Number of data in regression dataset: 56206
# Processing image 2197
# Number of data in SVM dataset: 56339
# Number of data in regression dataset: 56339
# Processing image 2198
# Number of data in SVM dataset: 56461
# Number of data in regression dataset: 56461
# Processing image 2199
# Number of data in SVM dataset: 56576
# Number of data in regression dataset: 56576
# Processing image 2200
# Number of data in SVM dataset: 56699
# Number of data in regression dataset: 56699

# %%
len(svm_dataset), len(regression_dataset)
# Out:
# (56699, 56699)

# %%
# Size in MB of svm_dataset and regression_dataset in memory

print('Size of svm_dataset:', sys.getsizeof(svm_dataset) / 1024 / 1024, 'MB')
print('Size of regression_dataset:', sys.getsizeof(regression_dataset) / 1024 / 1024, 'MB')
# Out:
# Size of svm_dataset: 0.42378997802734375 MB
# Size of regression_dataset: 0.42378997802734375 MB

# %%
# save the svm_dataset and regression_dataset to disk


with open('svm_dataset.pkl', 'wb') as f:
    pickle.dump(svm_dataset, f)

with open('regression_dataset.pkl', 'wb') as f:
    pickle.dump(regression_dataset, f)

# %%
# load svm_dataset.pkl and add new data to it

with open('svm_dataset.pkl', 'rb') as f:
    svm_dataset_pkl = pickle.load(f)


# load regression_dataset.pkl and add new data to it

with open('regression_dataset.pkl', 'rb') as f:
    regression_dataset_pkl = pickle.load(f)

# %%
len(svm_dataset_pkl), len(regression_dataset_pkl)
# Out:
# (251228, 251228)

# %%
svm_dataset_pkl.extend(svm_dataset)

regression_dataset_pkl.extend(regression_dataset)

# %%
len(svm_dataset_pkl), len(regression_dataset_pkl)
# Out:
# (307927, 307927)

# %%
with open('svm_dataset.pkl', 'wb') as f:
    pickle.dump(svm_dataset_pkl, f)

with open('regression_dataset.pkl', 'wb') as f:
    pickle.dump(regression_dataset_pkl, f)
