# %%
# %matplotlib inline
import os
import sys
import pickle

from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

import torchvision
from torchvision import models

import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset
import torch.optim as optim
from torchmetrics import Accuracy
from torchinfo import summary
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import VOCDetection

sys.path.append('../../')  
from Object_Detection.RCNN import selective_search
from Object_Detection.RCNN.bbox import calculate_iou
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# Settings 

torch.set_printoptions(precision=3)

# %%
voc_dataset = VOCDetection(root='./data', 
                           year='2012', 
                           image_set='train',
                           download=True, 
                        #    transform=transform
                           )
# Out:
# Using downloaded and verified file: ./data\VOCtrainval_11-May-2012.tar
# Extracting ./data\VOCtrainval_11-May-2012.tar to ./data

# %% [markdown]
# # Load model and its finetuned weights (PASCAL VOC)

# %%
# Step 1: Load the ResNet50 model without pretrained weights
resnet50 = models.resnet50(weights=False)

resnet50.fc = torch.nn.Linear(resnet50.fc.in_features, 20)
# Out:
# m:\ML\ML_regs\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Step 2: Load your finetuned weights
# Make sure that the path 'voc_finetune_resnet_weights.pth' is correct and accessible
resnet50.load_state_dict(torch.load('resnet50_pascal_voc.pth'))
# Out:
# <All keys matched successfully>

# %%
summary(model=resnet50, input_size=(1, 3, 227, 227), col_width=20,
                  col_names=['input_size', 'output_size', 'num_params', 'trainable'], row_settings=['var_names'], verbose=0)

# %%
class ResNet50Modified(nn.Module):
    def __init__(self, original_model):
        super(ResNet50Modified, self).__init__()
        # Adapt this line if your model was changed differently
        self.features = nn.Sequential(*list(original_model.children())[:-1])  # Typically removes the final fully connected layer and avg pooling layer

    def forward(self, x):
        x = self.features(x)
        return x

# Create the modified model with loaded weights
modified_resnet50 = ResNet50Modified(resnet50)

# Put the model in evaluation mode if you are doing inference or feature extraction
modified_resnet50.eval()

if torch.cuda.is_available():
    modified_resnet50 = modified_resnet50.cuda()

# %%
summary(model=modified_resnet50, input_size=(1, 3, 227, 227), col_width=20,
                  col_names=['input_size', 'output_size', 'num_params', 'trainable'], row_settings=['var_names'], verbose=0)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# ResNet50Modified (ResNet50Modified)           [1, 3, 227, 227]     [1, 2048, 1, 1]      --                   True
# ├─Sequential (features)                       [1, 3, 227, 227]     [1, 2048, 1, 1]      --                   True
# │    └─Conv2d (0)                             [1, 3, 227, 227]     [1, 64, 114, 114]    9,408                True
# │    └─BatchNorm2d (1)                        [1, 64, 114, 114]    [1, 64, 114, 114]    128                  True
# │    └─ReLU (2)                               [1, 64, 114, 114]    [1, 64, 114, 114]    --                   --
# │    └─MaxPool2d (3)                          [1, 64, 114, 114]    [1, 64, 57, 57]      --                   --
# │    └─Sequential (4)                         [1, 64, 57, 57]      [1, 256, 57, 57]     --                   True
# │    │    └─Bottleneck (0)                    [1, 64, 57, 57]      [1, 256, 57, 57]     75,008               True
# │    │    └─Bottleneck (1)                    [1, 256, 57, 57]     [1, 256, 57, 57]     70,400               True
# │    │    └─Bottleneck (2)                    [1, 256, 57, 57]     [1, 256, 57, 57]     70,400               True
# │    └─Sequential (5)                         [1, 256, 57, 57]     [1, 512, 29, 29]     --                   True
# │    │    └─Bottleneck (0)                    [1, 256, 57, 57]     [1, 512, 29, 29]     379,392              True
# │    │    └─Bottleneck (1)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    │    └─Bottleneck (2)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    │    └─Bottleneck (3)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    └─Sequential (6)                         [1, 512, 29, 29]     [1, 1024, 15, 15]    --                   True
# │    │    └─Bottleneck (0)                    [1, 512, 29, 29]     [1, 1024, 15, 15]    1,512,448            True
# │    │    └─Bottleneck (1)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (2)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (3)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (4)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (5)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    └─Sequential (7)                         [1, 1024, 15, 15]    [1, 2048, 8, 8]      --                   True
# │    │    └─Bottleneck (0)                    [1, 1024, 15, 15]    [1, 2048, 8, 8]      6,039,552            True
# │    │    └─Bottleneck (1)                    [1, 2048, 8, 8]      [1, 2048, 8, 8]      4,462,592            True
# │    │    └─Bottleneck (2)                    [1, 2048, 8, 8]      [1, 2048, 8, 8]      4,462,592            True
# │    └─AdaptiveAvgPool2d (8)                  [1, 2048, 8, 8]      [1, 2048, 1, 1]      --                   --
# =============================================================================================================================
# Total params: 23,508,032
# Trainable params: 23,508,032
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 4.63
# =============================================================================================================================
# Input size (MB): 0.62
# Forward/backward pass size (MB): 191.90
# Params size (MB): 94.03
# Estimated Total Size (MB): 286.55
# =============================================================================================================================

# %% [markdown]
# # Generate features

# %%
voc_dataset
# Out:
# Dataset VOCDetection
#     Number of datapoints: 5717
#     Root location: ./data

# %%
# Single image load from the VOC dataset and in numpy format

image, target = voc_dataset[0]
image_array = np.array(image)

# %%
preprocess = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def batch_process_features(model, regions):
    """ Process a batch of regions through the model """
    # Convert list of PIL images to tensor
    regions_tensor = torch.stack([preprocess(region) for region in regions]).cuda()
    
    # Extract features
    with torch.no_grad():
        features = model(regions_tensor)
    return features.cpu().numpy()

gs = selective_search.get_selective_search()

counter, start_index = 1500, 1500
svm_dataset = []
regression_dataset = []
# Assuming 'voc_dataset' is iterable with (image, annot)
for i in range(start_index, len(voc_dataset)):
    image, annot = voc_dataset[i]
    
    counter += 1
    # Counter for images processed
    print(f'Processing image {counter}')

    # Get proposals and annotations similar to your original code
    image_array = np.array(image)
    selective_search.config(gs, image_array, strategy='q')
    rects = selective_search.get_rects(gs)

    # Prepare annotations
    annotations = []
    for obj in annot['annotation']['object']:
        annotations.append({
            'class': obj['name'],
            'bbox': [int(obj['bndbox']['xmin']), int(obj['bndbox']['ymin']), int(obj['bndbox']['xmax']), int(obj['bndbox']['ymax'])]
        })

    # Collect regions for batch processing
    regions = [image.crop((x1, y1, x2, y2)) for x1, y1, x2, y2 in rects]

    # Process all regions at once in batches
    features = []
    for i in range(0, len(regions), 16):  # batch_size e.g., 32, 64, 128, 256, 512
        batch = regions[i:i + 16]
        batch_features = batch_process_features(modified_resnet50, batch)
        features.extend(batch_features)


    # Calculate IOUs and assign labels after extracting all features
    labels = []
    for proposal, feature in zip(rects, features):
        proposal_iou = {cls['class']: calculate_iou(proposal, cls['bbox']) for cls in annotations}
        best_iou = max(proposal_iou.values())
        if best_iou > 0.5:
            matched_class = max(proposal_iou, key=proposal_iou.get)
            labels.append((proposal, matched_class, 'positive'))
        else:
            labels.append((proposal, None, 'negative'))


    # Prepare datasets for SVM and regression

    for feature, label in zip(features, labels):
        if label[2] == 'positive':
            svm_dataset.append((feature, label[1]))
            ground_truth_bbox = next((item['bbox'] for item in annotations if item['class'] == label[1]), None)
            if ground_truth_bbox:
                tx = ground_truth_bbox[0] - label[0][0]
                ty = ground_truth_bbox[1] - label[0][1]
                tw = ground_truth_bbox[2] - label[0][2]
                th = ground_truth_bbox[3] - label[0][3]
                regression_dataset.append((feature, (tx, ty, tw, th)))
    print(f'Number of data in SVM dataset: {len(svm_dataset)}')
    print(f'Number of data in regression dataset: {len(regression_dataset)}')
    # break after 10 images
    if counter == 2200:
        break
# Out:
# Processing image 1501
# Number of data in SVM dataset: 221
# Number of data in regression dataset: 221
# Processing image 1502
# Number of data in SVM dataset: 333
# Number of data in regression dataset: 333
# Processing image 1503
# Number of data in SVM dataset: 426
# Number of data in regression dataset: 426
# Processing image 1504
# Number of data in SVM dataset: 565
# Number of data in regression dataset: 565
# Processing image 1505
# Number of data in SVM dataset: 747
# Number of data in regression dataset: 747
# Processing image 1506
# Number of data in SVM dataset: 869
# Number of data in regression dataset: 869
# Processing image 1507
# Number of data in SVM dataset: 978
# Number of data in regression dataset: 978
# Processing image 1508
# Number of data in SVM dataset: 1164
# Number of data in regression dataset: 1164
# Processing image 1509
# Number of data in SVM dataset: 1358
# Number of data in regression dataset: 1358
# Processing image 1510
# Number of data in SVM dataset: 1474
# Number of data in regression dataset: 1474
# Processing image 1511
# Number of data in SVM dataset: 1532
# Number of data in regression dataset: 1532
# Processing image 1512
# Number of data in SVM dataset: 1718
# Number of data in regression dataset: 1718
# Processing image 1513
# Number of data in SVM dataset: 1849
# Number of data in regression dataset: 1849
# Processing image 1514
# Number of data in SVM dataset: 2010
# Number of data in regression dataset: 2010
# Processing image 1515
# Number of data in SVM dataset: 2080
# Number of data in regression dataset: 2080
# Processing image 1516
# Number of data in SVM dataset: 2283
# Number of data in regression dataset: 2283
# Processing image 1517
# Number of data in SVM dataset: 2381
# Number of data in regression dataset: 2381
# Processing image 1518
# Number of data in SVM dataset: 2508
# Number of data in regression dataset: 2508
# Processing image 1519
# Number of data in SVM dataset: 2513
# Number of data in regression dataset: 2513
# Processing image 1520
# Number of data in SVM dataset: 2528
# Number of data in regression dataset: 2528
# Processing image 1521
# Number of data in SVM dataset: 2808
# Number of data in regression dataset: 2808
# Processing image 1522
# Number of data in SVM dataset: 2839
# Number of data in regression dataset: 2839
# Processing image 1523
# Number of data in SVM dataset: 3017
# Number of data in regression dataset: 3017
# Processing image 1524
# Number of data in SVM dataset: 3070
# Number of data in regression dataset: 3070
# Processing image 1525
# Number of data in SVM dataset: 3070
# Number of data in regression dataset: 3070
# Processing image 1526
# Number of data in SVM dataset: 3072
# Number of data in regression dataset: 3072
# Processing image 1527
# Number of data in SVM dataset: 3198
# Number of data in regression dataset: 3198
# Processing image 1528
# Number of data in SVM dataset: 3198
# Number of data in regression dataset: 3198
# Processing image 1529
# Number of data in SVM dataset: 3201
# Number of data in regression dataset: 3201
# Processing image 1530
# Number of data in SVM dataset: 3249
# Number of data in regression dataset: 3249
# Processing image 1531
# Number of data in SVM dataset: 3311
# Number of data in regression dataset: 3311
# Processing image 1532
# Number of data in SVM dataset: 3452
# Number of data in regression dataset: 3452
# Processing image 1533
# Number of data in SVM dataset: 3539
# Number of data in regression dataset: 3539
# Processing image 1534
# Number of data in SVM dataset: 3702
# Number of data in regression dataset: 3702
# Processing image 1535
# Number of data in SVM dataset: 3938
# Number of data in regression dataset: 3938
# Processing image 1536
# Number of data in SVM dataset: 4088
# Number of data in regression dataset: 4088
# Processing image 1537
# Number of data in SVM dataset: 4155
# Number of data in regression dataset: 4155
# Processing image 1538
# Number of data in SVM dataset: 4268
# Number of data in regression dataset: 4268
# Processing image 1539
# Number of data in SVM dataset: 4268
# Number of data in regression dataset: 4268
# Processing image 1540
# Number of data in SVM dataset: 4344
# Number of data in regression dataset: 4344
# Processing image 1541
# Number of data in SVM dataset: 4506
# Number of data in regression dataset: 4506
# Processing image 1542
# Number of data in SVM dataset: 4539
# Number of data in regression dataset: 4539
# Processing image 1543
# Number of data in SVM dataset: 4797
# Number of data in regression dataset: 4797
# Processing image 1544
# Number of data in SVM dataset: 4831
# Number of data in regression dataset: 4831
# Processing image 1545
# Number of data in SVM dataset: 4935
# Number of data in regression dataset: 4935
# Processing image 1546
# Number of data in SVM dataset: 5170
# Number of data in regression dataset: 5170
# Processing image 1547
# Number of data in SVM dataset: 5252
# Number of data in regression dataset: 5252
# Processing image 1548
# Number of data in SVM dataset: 5295
# Number of data in regression dataset: 5295
# Processing image 1549
# Number of data in SVM dataset: 5447
# Number of data in regression dataset: 5447
# Processing image 1550
# Number of data in SVM dataset: 5587
# Number of data in regression dataset: 5587
# Processing image 1551
# Number of data in SVM dataset: 5688
# Number of data in regression dataset: 5688
# Processing image 1552
# Number of data in SVM dataset: 5695
# Number of data in regression dataset: 5695
# Processing image 1553
# Number of data in SVM dataset: 5809
# Number of data in regression dataset: 5809
# Processing image 1554
# Number of data in SVM dataset: 5833
# Number of data in regression dataset: 5833
# Processing image 1555
# Number of data in SVM dataset: 5883
# Number of data in regression dataset: 5883
# Processing image 1556
# Number of data in SVM dataset: 5898
# Number of data in regression dataset: 5898
# Processing image 1557
# Number of data in SVM dataset: 5925
# Number of data in regression dataset: 5925
# Processing image 1558
# Number of data in SVM dataset: 6066
# Number of data in regression dataset: 6066
# Processing image 1559
# Number of data in SVM dataset: 6270
# Number of data in regression dataset: 6270
# Processing image 1560
# Number of data in SVM dataset: 6405
# Number of data in regression dataset: 6405
# Processing image 1561
# Number of data in SVM dataset: 6584
# Number of data in regression dataset: 6584
# Processing image 1562
# Number of data in SVM dataset: 6655
# Number of data in regression dataset: 6655
# Processing image 1563
# Number of data in SVM dataset: 6782
# Number of data in regression dataset: 6782
# Processing image 1564
# Number of data in SVM dataset: 6965
# Number of data in regression dataset: 6965
# Processing image 1565
# Number of data in SVM dataset: 7134
# Number of data in regression dataset: 7134
# Processing image 1566
# Number of data in SVM dataset: 7177
# Number of data in regression dataset: 7177
# Processing image 1567
# Number of data in SVM dataset: 7290
# Number of data in regression dataset: 7290
# Processing image 1568
# Number of data in SVM dataset: 7457
# Number of data in regression dataset: 7457
# Processing image 1569
# Number of data in SVM dataset: 7601
# Number of data in regression dataset: 7601
# Processing image 1570
# Number of data in SVM dataset: 7676
# Number of data in regression dataset: 7676
# Processing image 1571
# Number of data in SVM dataset: 7915
# Number of data in regression dataset: 7915
# Processing image 1572
# Number of data in SVM dataset: 7918
# Number of data in regression dataset: 7918
# Processing image 1573
# Number of data in SVM dataset: 7995
# Number of data in regression dataset: 7995
# Processing image 1574
# Number of data in SVM dataset: 8075
# Number of data in regression dataset: 8075
# Processing image 1575
# Number of data in SVM dataset: 8161
# Number of data in regression dataset: 8161
# Processing image 1576
# Number of data in SVM dataset: 8271
# Number of data in regression dataset: 8271
# Processing image 1577
# Number of data in SVM dataset: 8354
# Number of data in regression dataset: 8354
# Processing image 1578
# Number of data in SVM dataset: 8497
# Number of data in regression dataset: 8497
# Processing image 1579
# Number of data in SVM dataset: 8645
# Number of data in regression dataset: 8645
# Processing image 1580
# Number of data in SVM dataset: 8796
# Number of data in regression dataset: 8796
# Processing image 1581
# Number of data in SVM dataset: 8943
# Number of data in regression dataset: 8943
# Processing image 1582
# Number of data in SVM dataset: 9051
# Number of data in regression dataset: 9051
# Processing image 1583
# Number of data in SVM dataset: 9480
# Number of data in regression dataset: 9480
# Processing image 1584
# Number of data in SVM dataset: 9993
# Number of data in regression dataset: 9993
# Processing image 1585
# Number of data in SVM dataset: 10138
# Number of data in regression dataset: 10138
# Processing image 1586
# Number of data in SVM dataset: 10331
# Number of data in regression dataset: 10331
# Processing image 1587
# Number of data in SVM dataset: 10487
# Number of data in regression dataset: 10487
# Processing image 1588
# Number of data in SVM dataset: 10497
# Number of data in regression dataset: 10497
# Processing image 1589
# Number of data in SVM dataset: 10574
# Number of data in regression dataset: 10574
# Processing image 1590
# Number of data in SVM dataset: 10720
# Number of data in regression dataset: 10720
# Processing image 1591
# Number of data in SVM dataset: 10921
# Number of data in regression dataset: 10921
# Processing image 1592
# Number of data in SVM dataset: 11175
# Number of data in regression dataset: 11175
# Processing image 1593
# Number of data in SVM dataset: 11212
# Number of data in regression dataset: 11212
# Processing image 1594
# Number of data in SVM dataset: 11257
# Number of data in regression dataset: 11257
# Processing image 1595
# Number of data in SVM dataset: 11454
# Number of data in regression dataset: 11454
# Processing image 1596
# Number of data in SVM dataset: 11567
# Number of data in regression dataset: 11567
# Processing image 1597
# Number of data in SVM dataset: 11590
# Number of data in regression dataset: 11590
# Processing image 1598
# Number of data in SVM dataset: 12118
# Number of data in regression dataset: 12118
# Processing image 1599
# Number of data in SVM dataset: 12184
# Number of data in regression dataset: 12184
# Processing image 1600
# Number of data in SVM dataset: 12345
# Number of data in regression dataset: 12345
# Processing image 1601
# Number of data in SVM dataset: 12549
# Number of data in regression dataset: 12549
# Processing image 1602
# Number of data in SVM dataset: 12584
# Number of data in regression dataset: 12584
# Processing image 1603
# Number of data in SVM dataset: 12681
# Number of data in regression dataset: 12681
# Processing image 1604
# Number of data in SVM dataset: 12875
# Number of data in regression dataset: 12875
# Processing image 1605
# Number of data in SVM dataset: 12989
# Number of data in regression dataset: 12989
# Processing image 1606
# Number of data in SVM dataset: 13111
# Number of data in regression dataset: 13111
# Processing image 1607
# Number of data in SVM dataset: 13221
# Number of data in regression dataset: 13221
# Processing image 1608
# Number of data in SVM dataset: 13404
# Number of data in regression dataset: 13404
# Processing image 1609
# Number of data in SVM dataset: 13569
# Number of data in regression dataset: 13569
# Processing image 1610
# Number of data in SVM dataset: 13594
# Number of data in regression dataset: 13594
# Processing image 1611
# Number of data in SVM dataset: 13635
# Number of data in regression dataset: 13635
# Processing image 1612
# Number of data in SVM dataset: 13902
# Number of data in regression dataset: 13902
# Processing image 1613
# Number of data in SVM dataset: 14002
# Number of data in regression dataset: 14002
# Processing image 1614
# Number of data in SVM dataset: 14340
# Number of data in regression dataset: 14340
# Processing image 1615
# Number of data in SVM dataset: 14410
# Number of data in regression dataset: 14410
# Processing image 1616
# Number of data in SVM dataset: 14614
# Number of data in regression dataset: 14614
# Processing image 1617
# Number of data in SVM dataset: 14859
# Number of data in regression dataset: 14859
# Processing image 1618
# Number of data in SVM dataset: 14960
# Number of data in regression dataset: 14960
# Processing image 1619
# Number of data in SVM dataset: 15017
# Number of data in regression dataset: 15017
# Processing image 1620
# Number of data in SVM dataset: 15130
# Number of data in regression dataset: 15130
# Processing image 1621
# Number of data in SVM dataset: 15130
# Number of data in regression dataset: 15130
# Processing image 1622
# Number of data in SVM dataset: 15197
# Number of data in regression dataset: 15197
# Processing image 1623
# Number of data in SVM dataset: 15208
# Number of data in regression dataset: 15208
# Processing image 1624
# Number of data in SVM dataset: 15364
# Number of data in regression dataset: 15364
# Processing image 1625
# Number of data in SVM dataset: 15393
# Number of data in regression dataset: 15393
# Processing image 1626
# Number of data in SVM dataset: 15399
# Number of data in regression dataset: 15399
# Processing image 1627
# Number of data in SVM dataset: 15740
# Number of data in regression dataset: 15740
# Processing image 1628
# Number of data in SVM dataset: 15863
# Number of data in regression dataset: 15863
# Processing image 1629
# Number of data in SVM dataset: 15987
# Number of data in regression dataset: 15987
# Processing image 1630
# Number of data in SVM dataset: 16094
# Number of data in regression dataset: 16094
# Processing image 1631
# Number of data in SVM dataset: 16173
# Number of data in regression dataset: 16173
# Processing image 1632
# Number of data in SVM dataset: 16199
# Number of data in regression dataset: 16199
# Processing image 1633
# Number of data in SVM dataset: 16236
# Number of data in regression dataset: 16236
# Processing image 1634
# Number of data in SVM dataset: 16260
# Number of data in regression dataset: 16260
# Processing image 1635
# Number of data in SVM dataset: 16661
# Number of data in regression dataset: 16661
# Processing image 1636
# Number of data in SVM dataset: 16766
# Number of data in regression dataset: 16766
# Processing image 1637
# Number of data in SVM dataset: 16840
# Number of data in regression dataset: 16840
# Processing image 1638
# Number of data in SVM dataset: 17154
# Number of data in regression dataset: 17154
# Processing image 1639
# Number of data in SVM dataset: 17438
# Number of data in regression dataset: 17438
# Processing image 1640
# Number of data in SVM dataset: 17575
# Number of data in regression dataset: 17575
# Processing image 1641
# Number of data in SVM dataset: 17766
# Number of data in regression dataset: 17766
# Processing image 1642
# Number of data in SVM dataset: 17823
# Number of data in regression dataset: 17823
# Processing image 1643
# Number of data in SVM dataset: 17832
# Number of data in regression dataset: 17832
# Processing image 1644
# Number of data in SVM dataset: 17966
# Number of data in regression dataset: 17966
# Processing image 1645
# Number of data in SVM dataset: 18295
# Number of data in regression dataset: 18295
# Processing image 1646
# Number of data in SVM dataset: 18350
# Number of data in regression dataset: 18350
# Processing image 1647
# Number of data in SVM dataset: 18502
# Number of data in regression dataset: 18502
# Processing image 1648
# Number of data in SVM dataset: 18751
# Number of data in regression dataset: 18751
# Processing image 1649
# Number of data in SVM dataset: 18958
# Number of data in regression dataset: 18958
# Processing image 1650
# Number of data in SVM dataset: 18967
# Number of data in regression dataset: 18967
# Processing image 1651
# Number of data in SVM dataset: 19012
# Number of data in regression dataset: 19012
# Processing image 1652
# Number of data in SVM dataset: 19106
# Number of data in regression dataset: 19106
# Processing image 1653
# Number of data in SVM dataset: 19207
# Number of data in regression dataset: 19207
# Processing image 1654
# Number of data in SVM dataset: 19273
# Number of data in regression dataset: 19273
# Processing image 1655
# Number of data in SVM dataset: 19445
# Number of data in regression dataset: 19445
# Processing image 1656
# Number of data in SVM dataset: 19538
# Number of data in regression dataset: 19538
# Processing image 1657
# Number of data in SVM dataset: 19679
# Number of data in regression dataset: 19679
# Processing image 1658
# Number of data in SVM dataset: 19777
# Number of data in regression dataset: 19777
# Processing image 1659
# Number of data in SVM dataset: 19985
# Number of data in regression dataset: 19985
# Processing image 1660
# Number of data in SVM dataset: 20126
# Number of data in regression dataset: 20126
# Processing image 1661
# Number of data in SVM dataset: 20291
# Number of data in regression dataset: 20291
# Processing image 1662
# Number of data in SVM dataset: 20429
# Number of data in regression dataset: 20429
# Processing image 1663
# Number of data in SVM dataset: 20481
# Number of data in regression dataset: 20481
# Processing image 1664
# Number of data in SVM dataset: 20760
# Number of data in regression dataset: 20760
# Processing image 1665
# Number of data in SVM dataset: 20826
# Number of data in regression dataset: 20826
# Processing image 1666
# Number of data in SVM dataset: 20969
# Number of data in regression dataset: 20969
# Processing image 1667
# Number of data in SVM dataset: 21199
# Number of data in regression dataset: 21199
# Processing image 1668
# Number of data in SVM dataset: 21461
# Number of data in regression dataset: 21461
# Processing image 1669
# Number of data in SVM dataset: 21532
# Number of data in regression dataset: 21532
# Processing image 1670
# Number of data in SVM dataset: 21720
# Number of data in regression dataset: 21720
# Processing image 1671
# Number of data in SVM dataset: 21857
# Number of data in regression dataset: 21857
# Processing image 1672
# Number of data in SVM dataset: 21917
# Number of data in regression dataset: 21917
# Processing image 1673
# Number of data in SVM dataset: 22048
# Number of data in regression dataset: 22048
# Processing image 1674
# Number of data in SVM dataset: 22137
# Number of data in regression dataset: 22137
# Processing image 1675
# Number of data in SVM dataset: 22209
# Number of data in regression dataset: 22209
# Processing image 1676
# Number of data in SVM dataset: 22474
# Number of data in regression dataset: 22474
# Processing image 1677
# Number of data in SVM dataset: 22630
# Number of data in regression dataset: 22630
# Processing image 1678
# Number of data in SVM dataset: 22877
# Number of data in regression dataset: 22877
# Processing image 1679
# Number of data in SVM dataset: 22889
# Number of data in regression dataset: 22889
# Processing image 1680
# Number of data in SVM dataset: 22979
# Number of data in regression dataset: 22979
# Processing image 1681
# Number of data in SVM dataset: 23219
# Number of data in regression dataset: 23219
# Processing image 1682
# Number of data in SVM dataset: 23318
# Number of data in regression dataset: 23318
# Processing image 1683
# Number of data in SVM dataset: 23540
# Number of data in regression dataset: 23540
# Processing image 1684
# Number of data in SVM dataset: 23619
# Number of data in regression dataset: 23619
# Processing image 1685
# Number of data in SVM dataset: 23795
# Number of data in regression dataset: 23795
# Processing image 1686
# Number of data in SVM dataset: 23873
# Number of data in regression dataset: 23873
# Processing image 1687
# Number of data in SVM dataset: 23998
# Number of data in regression dataset: 23998
# Processing image 1688
# Number of data in SVM dataset: 24238
# Number of data in regression dataset: 24238
# Processing image 1689
# Number of data in SVM dataset: 24462
# Number of data in regression dataset: 24462
# Processing image 1690
# Number of data in SVM dataset: 24568
# Number of data in regression dataset: 24568
# Processing image 1691
# Number of data in SVM dataset: 24581
# Number of data in regression dataset: 24581
# Processing image 1692
# Number of data in SVM dataset: 24698
# Number of data in regression dataset: 24698
# Processing image 1693
# Number of data in SVM dataset: 24864
# Number of data in regression dataset: 24864
# Processing image 1694
# Number of data in SVM dataset: 24955
# Number of data in regression dataset: 24955
# Processing image 1695
# Number of data in SVM dataset: 25080
# Number of data in regression dataset: 25080
# Processing image 1696
# Number of data in SVM dataset: 25163
# Number of data in regression dataset: 25163
# Processing image 1697
# Number of data in SVM dataset: 25541
# Number of data in regression dataset: 25541
# Processing image 1698
# Number of data in SVM dataset: 25672
# Number of data in regression dataset: 25672
# Processing image 1699
# Number of data in SVM dataset: 25695
# Number of data in regression dataset: 25695
# Processing image 1700
# Number of data in SVM dataset: 25948
# Number of data in regression dataset: 25948
# Processing image 1701
# Number of data in SVM dataset: 25952
# Number of data in regression dataset: 25952
# Processing image 1702
# Number of data in SVM dataset: 26180
# Number of data in regression dataset: 26180
# Processing image 1703
# Number of data in SVM dataset: 26246
# Number of data in regression dataset: 26246
# Processing image 1704
# Number of data in SVM dataset: 26409
# Number of data in regression dataset: 26409
# Processing image 1705
# Number of data in SVM dataset: 26625
# Number of data in regression dataset: 26625
# Processing image 1706
# Number of data in SVM dataset: 26695
# Number of data in regression dataset: 26695
# Processing image 1707
# Number of data in SVM dataset: 26926
# Number of data in regression dataset: 26926
# Processing image 1708
# Number of data in SVM dataset: 27037
# Number of data in regression dataset: 27037
# Processing image 1709
# Number of data in SVM dataset: 27400
# Number of data in regression dataset: 27400
# Processing image 1710
# Number of data in SVM dataset: 27620
# Number of data in regression dataset: 27620
# Processing image 1711
# Number of data in SVM dataset: 27802
# Number of data in regression dataset: 27802
# Processing image 1712
# Number of data in SVM dataset: 28002
# Number of data in regression dataset: 28002
# Processing image 1713
# Number of data in SVM dataset: 28113
# Number of data in regression dataset: 28113
# Processing image 1714
# Number of data in SVM dataset: 28190
# Number of data in regression dataset: 28190
# Processing image 1715
# Number of data in SVM dataset: 28312
# Number of data in regression dataset: 28312
# Processing image 1716
# Number of data in SVM dataset: 28475
# Number of data in regression dataset: 28475
# Processing image 1717
# Number of data in SVM dataset: 28567
# Number of data in regression dataset: 28567
# Processing image 1718
# Number of data in SVM dataset: 28652
# Number of data in regression dataset: 28652
# Processing image 1719
# Number of data in SVM dataset: 28996
# Number of data in regression dataset: 28996
# Processing image 1720
# Number of data in SVM dataset: 29041
# Number of data in regression dataset: 29041
# Processing image 1721
# Number of data in SVM dataset: 29199
# Number of data in regression dataset: 29199
# Processing image 1722
# Number of data in SVM dataset: 29256
# Number of data in regression dataset: 29256
# Processing image 1723
# Number of data in SVM dataset: 29430
# Number of data in regression dataset: 29430
# Processing image 1724
# Number of data in SVM dataset: 29461
# Number of data in regression dataset: 29461
# Processing image 1725
# Number of data in SVM dataset: 29490
# Number of data in regression dataset: 29490
# Processing image 1726
# Number of data in SVM dataset: 29710
# Number of data in regression dataset: 29710
# Processing image 1727
# Number of data in SVM dataset: 29831
# Number of data in regression dataset: 29831
# Processing image 1728
# Number of data in SVM dataset: 30080
# Number of data in regression dataset: 30080
# Processing image 1729
# Number of data in SVM dataset: 30277
# Number of data in regression dataset: 30277
# Processing image 1730
# Number of data in SVM dataset: 30579
# Number of data in regression dataset: 30579
# Processing image 1731
# Number of data in SVM dataset: 30764
# Number of data in regression dataset: 30764
# Processing image 1732
# Number of data in SVM dataset: 30951
# Number of data in regression dataset: 30951
# Processing image 1733
# Number of data in SVM dataset: 30984
# Number of data in regression dataset: 30984
# Processing image 1734
# Number of data in SVM dataset: 31187
# Number of data in regression dataset: 31187
# Processing image 1735
# Number of data in SVM dataset: 31465
# Number of data in regression dataset: 31465
# Processing image 1736
# Number of data in SVM dataset: 31520
# Number of data in regression dataset: 31520
# Processing image 1737
# Number of data in SVM dataset: 31536
# Number of data in regression dataset: 31536
# Processing image 1738
# Number of data in SVM dataset: 31536
# Number of data in regression dataset: 31536
# Processing image 1739
# Number of data in SVM dataset: 32043
# Number of data in regression dataset: 32043
# Processing image 1740
# Number of data in SVM dataset: 32058
# Number of data in regression dataset: 32058
# Processing image 1741
# Number of data in SVM dataset: 32243
# Number of data in regression dataset: 32243
# Processing image 1742
# Number of data in SVM dataset: 32737
# Number of data in regression dataset: 32737
# Processing image 1743
# Number of data in SVM dataset: 32922
# Number of data in regression dataset: 32922
# Processing image 1744
# Number of data in SVM dataset: 33096
# Number of data in regression dataset: 33096
# Processing image 1745
# Number of data in SVM dataset: 33337
# Number of data in regression dataset: 33337
# Processing image 1746
# Number of data in SVM dataset: 33602
# Number of data in regression dataset: 33602
# Processing image 1747
# Number of data in SVM dataset: 33656
# Number of data in regression dataset: 33656
# Processing image 1748
# Number of data in SVM dataset: 33949
# Number of data in regression dataset: 33949
# Processing image 1749
# Number of data in SVM dataset: 34115
# Number of data in regression dataset: 34115
# Processing image 1750
# Number of data in SVM dataset: 34329
# Number of data in regression dataset: 34329
# Processing image 1751
# Number of data in SVM dataset: 34579
# Number of data in regression dataset: 34579
# Processing image 1752
# Number of data in SVM dataset: 34699
# Number of data in regression dataset: 34699
# Processing image 1753
# Number of data in SVM dataset: 34756
# Number of data in regression dataset: 34756
# Processing image 1754
# Number of data in SVM dataset: 34864
# Number of data in regression dataset: 34864
# Processing image 1755
# Number of data in SVM dataset: 35031
# Number of data in regression dataset: 35031
# Processing image 1756
# Number of data in SVM dataset: 35067
# Number of data in regression dataset: 35067
# Processing image 1757
# Number of data in SVM dataset: 35113
# Number of data in regression dataset: 35113
# Processing image 1758
# Number of data in SVM dataset: 35121
# Number of data in regression dataset: 35121
# Processing image 1759
# Number of data in SVM dataset: 35190
# Number of data in regression dataset: 35190
# Processing image 1760
# Number of data in SVM dataset: 35487
# Number of data in regression dataset: 35487
# Processing image 1761
# Number of data in SVM dataset: 35544
# Number of data in regression dataset: 35544
# Processing image 1762
# Number of data in SVM dataset: 35798
# Number of data in regression dataset: 35798
# Processing image 1763
# Number of data in SVM dataset: 36061
# Number of data in regression dataset: 36061
# Processing image 1764
# Number of data in SVM dataset: 36337
# Number of data in regression dataset: 36337
# Processing image 1765
# Number of data in SVM dataset: 36587
# Number of data in regression dataset: 36587
# Processing image 1766
# Number of data in SVM dataset: 36587
# Number of data in regression dataset: 36587
# Processing image 1767
# Number of data in SVM dataset: 36826
# Number of data in regression dataset: 36826
# Processing image 1768
# Number of data in SVM dataset: 36963
# Number of data in regression dataset: 36963
# Processing image 1769
# Number of data in SVM dataset: 37140
# Number of data in regression dataset: 37140
# Processing image 1770
# Number of data in SVM dataset: 37275
# Number of data in regression dataset: 37275
# Processing image 1771
# Number of data in SVM dataset: 37500
# Number of data in regression dataset: 37500
# Processing image 1772
# Number of data in SVM dataset: 37651
# Number of data in regression dataset: 37651
# Processing image 1773
# Number of data in SVM dataset: 37925
# Number of data in regression dataset: 37925
# Processing image 1774
# Number of data in SVM dataset: 38114
# Number of data in regression dataset: 38114
# Processing image 1775
# Number of data in SVM dataset: 38117
# Number of data in regression dataset: 38117
# Processing image 1776
# Number of data in SVM dataset: 38144
# Number of data in regression dataset: 38144
# Processing image 1777
# Number of data in SVM dataset: 38179
# Number of data in regression dataset: 38179
# Processing image 1778
# Number of data in SVM dataset: 38211
# Number of data in regression dataset: 38211
# Processing image 1779
# Number of data in SVM dataset: 38527
# Number of data in regression dataset: 38527
# Processing image 1780
# Number of data in SVM dataset: 38617
# Number of data in regression dataset: 38617
# Processing image 1781
# Number of data in SVM dataset: 38706
# Number of data in regression dataset: 38706
# Processing image 1782
# Number of data in SVM dataset: 38814
# Number of data in regression dataset: 38814
# Processing image 1783
# Number of data in SVM dataset: 38815
# Number of data in regression dataset: 38815
# Processing image 1784
# Number of data in SVM dataset: 38826
# Number of data in regression dataset: 38826
# Processing image 1785
# Number of data in SVM dataset: 38922
# Number of data in regression dataset: 38922
# Processing image 1786
# Number of data in SVM dataset: 38963
# Number of data in regression dataset: 38963
# Processing image 1787
# Number of data in SVM dataset: 39201
# Number of data in regression dataset: 39201
# Processing image 1788
# Number of data in SVM dataset: 39302
# Number of data in regression dataset: 39302
# Processing image 1789
# Number of data in SVM dataset: 39405
# Number of data in regression dataset: 39405
# Processing image 1790
# Number of data in SVM dataset: 39405
# Number of data in regression dataset: 39405
# Processing image 1791
# Number of data in SVM dataset: 39456
# Number of data in regression dataset: 39456
# Processing image 1792
# Number of data in SVM dataset: 39746
# Number of data in regression dataset: 39746
# Processing image 1793
# Number of data in SVM dataset: 39921
# Number of data in regression dataset: 39921
# Processing image 1794
# Number of data in SVM dataset: 40034
# Number of data in regression dataset: 40034
# Processing image 1795
# Number of data in SVM dataset: 40115
# Number of data in regression dataset: 40115
# Processing image 1796
# Number of data in SVM dataset: 40116
# Number of data in regression dataset: 40116
# Processing image 1797
# Number of data in SVM dataset: 40304
# Number of data in regression dataset: 40304
# Processing image 1798
# Number of data in SVM dataset: 40582
# Number of data in regression dataset: 40582
# Processing image 1799
# Number of data in SVM dataset: 40638
# Number of data in regression dataset: 40638
# Processing image 1800
# Number of data in SVM dataset: 40909
# Number of data in regression dataset: 40909
# Processing image 1801
# Number of data in SVM dataset: 41170
# Number of data in regression dataset: 41170
# Processing image 1802
# Number of data in SVM dataset: 41180
# Number of data in regression dataset: 41180
# Processing image 1803
# Number of data in SVM dataset: 41259
# Number of data in regression dataset: 41259
# Processing image 1804
# Number of data in SVM dataset: 41302
# Number of data in regression dataset: 41302
# Processing image 1805
# Number of data in SVM dataset: 41467
# Number of data in regression dataset: 41467
# Processing image 1806
# Number of data in SVM dataset: 41674
# Number of data in regression dataset: 41674
# Processing image 1807
# Number of data in SVM dataset: 41716
# Number of data in regression dataset: 41716
# Processing image 1808
# Number of data in SVM dataset: 41844
# Number of data in regression dataset: 41844
# Processing image 1809
# Number of data in SVM dataset: 41872
# Number of data in regression dataset: 41872
# Processing image 1810
# Number of data in SVM dataset: 42048
# Number of data in regression dataset: 42048
# Processing image 1811
# Number of data in SVM dataset: 42255
# Number of data in regression dataset: 42255
# Processing image 1812
# Number of data in SVM dataset: 42309
# Number of data in regression dataset: 42309
# Processing image 1813
# Number of data in SVM dataset: 42632
# Number of data in regression dataset: 42632
# Processing image 1814
# Number of data in SVM dataset: 42660
# Number of data in regression dataset: 42660
# Processing image 1815
# Number of data in SVM dataset: 42750
# Number of data in regression dataset: 42750
# Processing image 1816
# Number of data in SVM dataset: 42982
# Number of data in regression dataset: 42982
# Processing image 1817
# Number of data in SVM dataset: 43039
# Number of data in regression dataset: 43039
# Processing image 1818
# Number of data in SVM dataset: 43274
# Number of data in regression dataset: 43274
# Processing image 1819
# Number of data in SVM dataset: 43278
# Number of data in regression dataset: 43278
# Processing image 1820
# Number of data in SVM dataset: 43376
# Number of data in regression dataset: 43376
# Processing image 1821
# Number of data in SVM dataset: 43398
# Number of data in regression dataset: 43398
# Processing image 1822
# Number of data in SVM dataset: 43637
# Number of data in regression dataset: 43637
# Processing image 1823
# Number of data in SVM dataset: 43651
# Number of data in regression dataset: 43651
# Processing image 1824
# Number of data in SVM dataset: 43975
# Number of data in regression dataset: 43975
# Processing image 1825
# Number of data in SVM dataset: 44312
# Number of data in regression dataset: 44312
# Processing image 1826
# Number of data in SVM dataset: 44447
# Number of data in regression dataset: 44447
# Processing image 1827
# Number of data in SVM dataset: 44622
# Number of data in regression dataset: 44622
# Processing image 1828
# Number of data in SVM dataset: 44787
# Number of data in regression dataset: 44787
# Processing image 1829
# Number of data in SVM dataset: 45024
# Number of data in regression dataset: 45024
# Processing image 1830
# Number of data in SVM dataset: 45337
# Number of data in regression dataset: 45337
# Processing image 1831
# Number of data in SVM dataset: 45408
# Number of data in regression dataset: 45408
# Processing image 1832
# Number of data in SVM dataset: 45578
# Number of data in regression dataset: 45578
# Processing image 1833
# Number of data in SVM dataset: 45609
# Number of data in regression dataset: 45609
# Processing image 1834
# Number of data in SVM dataset: 45882
# Number of data in regression dataset: 45882
# Processing image 1835
# Number of data in SVM dataset: 46162
# Number of data in regression dataset: 46162
# Processing image 1836
# Number of data in SVM dataset: 46177
# Number of data in regression dataset: 46177
# Processing image 1837
# Number of data in SVM dataset: 46332
# Number of data in regression dataset: 46332
# Processing image 1838
# Number of data in SVM dataset: 46540
# Number of data in regression dataset: 46540
# Processing image 1839
# Number of data in SVM dataset: 46765
# Number of data in regression dataset: 46765
# Processing image 1840
# Number of data in SVM dataset: 46850
# Number of data in regression dataset: 46850
# Processing image 1841
# Number of data in SVM dataset: 47079
# Number of data in regression dataset: 47079
# Processing image 1842
# Number of data in SVM dataset: 47397
# Number of data in regression dataset: 47397
# Processing image 1843
# Number of data in SVM dataset: 47478
# Number of data in regression dataset: 47478
# Processing image 1844
# Number of data in SVM dataset: 47484
# Number of data in regression dataset: 47484
# Processing image 1845
# Number of data in SVM dataset: 47531
# Number of data in regression dataset: 47531
# Processing image 1846
# Number of data in SVM dataset: 47853
# Number of data in regression dataset: 47853
# Processing image 1847
# Number of data in SVM dataset: 48206
# Number of data in regression dataset: 48206
# Processing image 1848
# Number of data in SVM dataset: 48388
# Number of data in regression dataset: 48388
# Processing image 1849
# Number of data in SVM dataset: 48568
# Number of data in regression dataset: 48568
# Processing image 1850
# Number of data in SVM dataset: 48645
# Number of data in regression dataset: 48645
# Processing image 1851
# Number of data in SVM dataset: 48695
# Number of data in regression dataset: 48695
# Processing image 1852
# Number of data in SVM dataset: 48922
# Number of data in regression dataset: 48922
# Processing image 1853
# Number of data in SVM dataset: 49000
# Number of data in regression dataset: 49000
# Processing image 1854
# Number of data in SVM dataset: 49024
# Number of data in regression dataset: 49024
# Processing image 1855
# Number of data in SVM dataset: 49062
# Number of data in regression dataset: 49062
# Processing image 1856
# Number of data in SVM dataset: 49238
# Number of data in regression dataset: 49238
# Processing image 1857
# Number of data in SVM dataset: 49424
# Number of data in regression dataset: 49424
# Processing image 1858
# Number of data in SVM dataset: 49483
# Number of data in regression dataset: 49483
# Processing image 1859
# Number of data in SVM dataset: 49579
# Number of data in regression dataset: 49579
# Processing image 1860
# Number of data in SVM dataset: 49688
# Number of data in regression dataset: 49688
# Processing image 1861
# Number of data in SVM dataset: 49798
# Number of data in regression dataset: 49798
# Processing image 1862
# Number of data in SVM dataset: 49886
# Number of data in regression dataset: 49886
# Processing image 1863
# Number of data in SVM dataset: 49997
# Number of data in regression dataset: 49997
# Processing image 1864
# Number of data in SVM dataset: 50168
# Number of data in regression dataset: 50168
# Processing image 1865
# Number of data in SVM dataset: 50317
# Number of data in regression dataset: 50317
# Processing image 1866
# Number of data in SVM dataset: 50392
# Number of data in regression dataset: 50392
# Processing image 1867
# Number of data in SVM dataset: 50467
# Number of data in regression dataset: 50467
# Processing image 1868
# Number of data in SVM dataset: 50468
# Number of data in regression dataset: 50468
# Processing image 1869
# Number of data in SVM dataset: 50568
# Number of data in regression dataset: 50568
# Processing image 1870
# Number of data in SVM dataset: 50674
# Number of data in regression dataset: 50674
# Processing image 1871
# Number of data in SVM dataset: 50717
# Number of data in regression dataset: 50717
# Processing image 1872
# Number of data in SVM dataset: 51042
# Number of data in regression dataset: 51042
# Processing image 1873
# Number of data in SVM dataset: 51274
# Number of data in regression dataset: 51274
# Processing image 1874
# Number of data in SVM dataset: 51532
# Number of data in regression dataset: 51532
# Processing image 1875
# Number of data in SVM dataset: 51592
# Number of data in regression dataset: 51592
# Processing image 1876
# Number of data in SVM dataset: 51817
# Number of data in regression dataset: 51817
# Processing image 1877
# Number of data in SVM dataset: 51910
# Number of data in regression dataset: 51910
# Processing image 1878
# Number of data in SVM dataset: 52071
# Number of data in regression dataset: 52071
# Processing image 1879
# Number of data in SVM dataset: 52327
# Number of data in regression dataset: 52327
# Processing image 1880
# Number of data in SVM dataset: 52390
# Number of data in regression dataset: 52390
# Processing image 1881
# Number of data in SVM dataset: 52578
# Number of data in regression dataset: 52578
# Processing image 1882
# Number of data in SVM dataset: 52696
# Number of data in regression dataset: 52696
# Processing image 1883
# Number of data in SVM dataset: 52746
# Number of data in regression dataset: 52746
# Processing image 1884
# Number of data in SVM dataset: 52968
# Number of data in regression dataset: 52968
# Processing image 1885
# Number of data in SVM dataset: 52968
# Number of data in regression dataset: 52968
# Processing image 1886
# Number of data in SVM dataset: 53114
# Number of data in regression dataset: 53114
# Processing image 1887
# Number of data in SVM dataset: 53228
# Number of data in regression dataset: 53228
# Processing image 1888
# Number of data in SVM dataset: 53231
# Number of data in regression dataset: 53231
# Processing image 1889
# Number of data in SVM dataset: 53415
# Number of data in regression dataset: 53415
# Processing image 1890
# Number of data in SVM dataset: 53503
# Number of data in regression dataset: 53503
# Processing image 1891
# Number of data in SVM dataset: 53852
# Number of data in regression dataset: 53852
# Processing image 1892
# Number of data in SVM dataset: 53969
# Number of data in regression dataset: 53969
# Processing image 1893
# Number of data in SVM dataset: 54261
# Number of data in regression dataset: 54261
# Processing image 1894
# Number of data in SVM dataset: 54353
# Number of data in regression dataset: 54353
# Processing image 1895
# Number of data in SVM dataset: 54488
# Number of data in regression dataset: 54488
# Processing image 1896
# Number of data in SVM dataset: 54600
# Number of data in regression dataset: 54600
# Processing image 1897
# Number of data in SVM dataset: 54643
# Number of data in regression dataset: 54643
# Processing image 1898
# Number of data in SVM dataset: 54661
# Number of data in regression dataset: 54661
# Processing image 1899
# Number of data in SVM dataset: 54693
# Number of data in regression dataset: 54693
# Processing image 1900
# Number of data in SVM dataset: 54867
# Number of data in regression dataset: 54867
# Processing image 1901
# Number of data in SVM dataset: 54888
# Number of data in regression dataset: 54888
# Processing image 1902
# Number of data in SVM dataset: 55074
# Number of data in regression dataset: 55074
# Processing image 1903
# Number of data in SVM dataset: 55166
# Number of data in regression dataset: 55166
# Processing image 1904
# Number of data in SVM dataset: 55190
# Number of data in regression dataset: 55190
# Processing image 1905
# Number of data in SVM dataset: 55377
# Number of data in regression dataset: 55377
# Processing image 1906
# Number of data in SVM dataset: 55461
# Number of data in regression dataset: 55461
# Processing image 1907
# Number of data in SVM dataset: 55507
# Number of data in regression dataset: 55507
# Processing image 1908
# Number of data in SVM dataset: 55718
# Number of data in regression dataset: 55718
# Processing image 1909
# Number of data in SVM dataset: 55781
# Number of data in regression dataset: 55781
# Processing image 1910
# Number of data in SVM dataset: 55907
# Number of data in regression dataset: 55907
# Processing image 1911
# Number of data in SVM dataset: 56088
# Number of data in regression dataset: 56088
# Processing image 1912
# Number of data in SVM dataset: 56338
# Number of data in regression dataset: 56338
# Processing image 1913
# Number of data in SVM dataset: 56632
# Number of data in regression dataset: 56632
# Processing image 1914
# Number of data in SVM dataset: 56971
# Number of data in regression dataset: 56971
# Processing image 1915
# Number of data in SVM dataset: 56980
# Number of data in regression dataset: 56980
# Processing image 1916
# Number of data in SVM dataset: 57258
# Number of data in regression dataset: 57258
# Processing image 1917
# Number of data in SVM dataset: 57428
# Number of data in regression dataset: 57428
# Processing image 1918
# Number of data in SVM dataset: 57470
# Number of data in regression dataset: 57470
# Processing image 1919
# Number of data in SVM dataset: 57510
# Number of data in regression dataset: 57510
# Processing image 1920
# Number of data in SVM dataset: 57602
# Number of data in regression dataset: 57602
# Processing image 1921
# Number of data in SVM dataset: 57703
# Number of data in regression dataset: 57703
# Processing image 1922
# Number of data in SVM dataset: 57736
# Number of data in regression dataset: 57736
# Processing image 1923
# Number of data in SVM dataset: 57837
# Number of data in regression dataset: 57837
# Processing image 1924
# Number of data in SVM dataset: 57931
# Number of data in regression dataset: 57931
# Processing image 1925
# Number of data in SVM dataset: 58012
# Number of data in regression dataset: 58012
# Processing image 1926
# Number of data in SVM dataset: 58218
# Number of data in regression dataset: 58218
# Processing image 1927
# Number of data in SVM dataset: 58400
# Number of data in regression dataset: 58400
# Processing image 1928
# Number of data in SVM dataset: 58449
# Number of data in regression dataset: 58449
# Processing image 1929
# Number of data in SVM dataset: 58590
# Number of data in regression dataset: 58590
# Processing image 1930
# Number of data in SVM dataset: 58716
# Number of data in regression dataset: 58716
# Processing image 1931
# Number of data in SVM dataset: 58988
# Number of data in regression dataset: 58988
# Processing image 1932
# Number of data in SVM dataset: 59070
# Number of data in regression dataset: 59070
# Processing image 1933
# Number of data in SVM dataset: 59134
# Number of data in regression dataset: 59134
# Processing image 1934
# Number of data in SVM dataset: 59180
# Number of data in regression dataset: 59180
# Processing image 1935
# Number of data in SVM dataset: 59450
# Number of data in regression dataset: 59450
# Processing image 1936
# Number of data in SVM dataset: 59489
# Number of data in regression dataset: 59489
# Processing image 1937
# Number of data in SVM dataset: 59737
# Number of data in regression dataset: 59737
# Processing image 1938
# Number of data in SVM dataset: 59951
# Number of data in regression dataset: 59951
# Processing image 1939
# Number of data in SVM dataset: 59951
# Number of data in regression dataset: 59951
# Processing image 1940
# Number of data in SVM dataset: 60050
# Number of data in regression dataset: 60050
# Processing image 1941
# Number of data in SVM dataset: 60387
# Number of data in regression dataset: 60387
# Processing image 1942
# Number of data in SVM dataset: 60545
# Number of data in regression dataset: 60545
# Processing image 1943
# Number of data in SVM dataset: 60558
# Number of data in regression dataset: 60558
# Processing image 1944
# Number of data in SVM dataset: 60653
# Number of data in regression dataset: 60653
# Processing image 1945
# Number of data in SVM dataset: 60912
# Number of data in regression dataset: 60912
# Processing image 1946
# Number of data in SVM dataset: 61122
# Number of data in regression dataset: 61122
# Processing image 1947
# Number of data in SVM dataset: 61196
# Number of data in regression dataset: 61196
# Processing image 1948
# Number of data in SVM dataset: 61463
# Number of data in regression dataset: 61463
# Processing image 1949
# Number of data in SVM dataset: 61654
# Number of data in regression dataset: 61654
# Processing image 1950
# Number of data in SVM dataset: 61807
# Number of data in regression dataset: 61807
# Processing image 1951
# Number of data in SVM dataset: 62119
# Number of data in regression dataset: 62119
# Processing image 1952
# Number of data in SVM dataset: 62165
# Number of data in regression dataset: 62165
# Processing image 1953
# Number of data in SVM dataset: 62237
# Number of data in regression dataset: 62237
# Processing image 1954
# Number of data in SVM dataset: 62558
# Number of data in regression dataset: 62558
# Processing image 1955
# Number of data in SVM dataset: 62763
# Number of data in regression dataset: 62763
# Processing image 1956
# Number of data in SVM dataset: 62789
# Number of data in regression dataset: 62789
# Processing image 1957
# Number of data in SVM dataset: 63116
# Number of data in regression dataset: 63116
# Processing image 1958
# Number of data in SVM dataset: 63281
# Number of data in regression dataset: 63281
# Processing image 1959
# Number of data in SVM dataset: 63511
# Number of data in regression dataset: 63511
# Processing image 1960
# Number of data in SVM dataset: 63588
# Number of data in regression dataset: 63588
# Processing image 1961
# Number of data in SVM dataset: 63702
# Number of data in regression dataset: 63702
# Processing image 1962
# Number of data in SVM dataset: 63865
# Number of data in regression dataset: 63865
# Processing image 1963
# Number of data in SVM dataset: 64019
# Number of data in regression dataset: 64019
# Processing image 1964
# Number of data in SVM dataset: 64133
# Number of data in regression dataset: 64133
# Processing image 1965
# Number of data in SVM dataset: 64201
# Number of data in regression dataset: 64201
# Processing image 1966
# Number of data in SVM dataset: 64323
# Number of data in regression dataset: 64323
# Processing image 1967
# Number of data in SVM dataset: 64497
# Number of data in regression dataset: 64497
# Processing image 1968
# Number of data in SVM dataset: 64613
# ...
# Processing image 2046
# Number of data in SVM dataset: 74567
# Number of data in regression dataset: 74567
# Processing image 2047
# Number of data in SVM dataset: 74661
# Number of data in regression dataset: 74661
# Processing image 2048
# Number of data in SVM dataset: 75040
# Number of data in regression dataset: 75040
# Processing image 2049
# Number of data in SVM dataset: 75351
# Number of data in regression dataset: 75351
# Processing image 2050
# Number of data in SVM dataset: 75356
# Number of data in regression dataset: 75356
# Processing image 2051
# Number of data in SVM dataset: 75542
# Number of data in regression dataset: 75542
# Processing image 2052
# Number of data in SVM dataset: 75793
# Number of data in regression dataset: 75793
# Processing image 2053
# Number of data in SVM dataset: 75957
# Number of data in regression dataset: 75957
# Processing image 2054
# Number of data in SVM dataset: 76070
# Number of data in regression dataset: 76070
# Processing image 2055
# Number of data in SVM dataset: 76215
# Number of data in regression dataset: 76215
# Processing image 2056
# Number of data in SVM dataset: 76235
# Number of data in regression dataset: 76235
# Processing image 2057
# Number of data in SVM dataset: 76344
# Number of data in regression dataset: 76344
# Processing image 2058
# Number of data in SVM dataset: 76354
# Number of data in regression dataset: 76354
# Processing image 2059
# Number of data in SVM dataset: 76547
# Number of data in regression dataset: 76547
# Processing image 2060
# Number of data in SVM dataset: 76586
# Number of data in regression dataset: 76586
# Processing image 2061
# Number of data in SVM dataset: 76767
# Number of data in regression dataset: 76767
# Processing image 2062
# Number of data in SVM dataset: 77066
# Number of data in regression dataset: 77066
# Processing image 2063
# Number of data in SVM dataset: 77314
# Number of data in regression dataset: 77314
# Processing image 2064
# Number of data in SVM dataset: 77481
# Number of data in regression dataset: 77481
# Processing image 2065
# Number of data in SVM dataset: 77794
# Number of data in regression dataset: 77794
# Processing image 2066
# Number of data in SVM dataset: 77850
# Number of data in regression dataset: 77850
# Processing image 2067
# Number of data in SVM dataset: 78214
# Number of data in regression dataset: 78214
# Processing image 2068
# Number of data in SVM dataset: 78320
# Number of data in regression dataset: 78320
# Processing image 2069
# Number of data in SVM dataset: 78825
# Number of data in regression dataset: 78825
# Processing image 2070
# Number of data in SVM dataset: 78973
# Number of data in regression dataset: 78973
# Processing image 2071
# Number of data in SVM dataset: 78977
# Number of data in regression dataset: 78977
# Processing image 2072
# Number of data in SVM dataset: 79124
# Number of data in regression dataset: 79124
# Processing image 2073
# Number of data in SVM dataset: 79324
# Number of data in regression dataset: 79324
# Processing image 2074
# Number of data in SVM dataset: 79454
# Number of data in regression dataset: 79454
# Processing image 2075
# Number of data in SVM dataset: 79663
# Number of data in regression dataset: 79663
# Processing image 2076
# Number of data in SVM dataset: 79713
# Number of data in regression dataset: 79713
# Processing image 2077
# Number of data in SVM dataset: 79897
# Number of data in regression dataset: 79897
# Processing image 2078
# Number of data in SVM dataset: 79897
# Number of data in regression dataset: 79897
# Processing image 2079
# Number of data in SVM dataset: 80045
# Number of data in regression dataset: 80045
# Processing image 2080
# Number of data in SVM dataset: 80373
# Number of data in regression dataset: 80373
# Processing image 2081
# Number of data in SVM dataset: 80530
# Number of data in regression dataset: 80530
# Processing image 2082
# Number of data in SVM dataset: 80872
# Number of data in regression dataset: 80872
# Processing image 2083
# Number of data in SVM dataset: 81042
# Number of data in regression dataset: 81042
# Processing image 2084
# Number of data in SVM dataset: 81143
# Number of data in regression dataset: 81143
# Processing image 2085
# Number of data in SVM dataset: 81167
# Number of data in regression dataset: 81167
# Processing image 2086
# Number of data in SVM dataset: 81174
# Number of data in regression dataset: 81174
# Processing image 2087
# Number of data in SVM dataset: 81426
# Number of data in regression dataset: 81426
# Processing image 2088
# Number of data in SVM dataset: 81503
# Number of data in regression dataset: 81503
# Processing image 2089
# Number of data in SVM dataset: 81725
# Number of data in regression dataset: 81725
# Processing image 2090
# Number of data in SVM dataset: 81985
# Number of data in regression dataset: 81985
# Processing image 2091
# Number of data in SVM dataset: 82051
# Number of data in regression dataset: 82051
# Processing image 2092
# Number of data in SVM dataset: 82224
# Number of data in regression dataset: 82224
# Processing image 2093
# Number of data in SVM dataset: 82415
# Number of data in regression dataset: 82415
# Processing image 2094
# Number of data in SVM dataset: 82712
# Number of data in regression dataset: 82712
# Processing image 2095
# Number of data in SVM dataset: 82945
# Number of data in regression dataset: 82945
# Processing image 2096
# Number of data in SVM dataset: 83077
# Number of data in regression dataset: 83077
# Processing image 2097
# Number of data in SVM dataset: 83150
# Number of data in regression dataset: 83150
# Processing image 2098
# Number of data in SVM dataset: 83184
# Number of data in regression dataset: 83184
# Processing image 2099
# Number of data in SVM dataset: 83198
# Number of data in regression dataset: 83198
# Processing image 2100
# Number of data in SVM dataset: 83250
# Number of data in regression dataset: 83250
# Processing image 2101
# Number of data in SVM dataset: 83259
# Number of data in regression dataset: 83259
# Processing image 2102
# Number of data in SVM dataset: 83359
# Number of data in regression dataset: 83359
# Processing image 2103
# Number of data in SVM dataset: 83381
# Number of data in regression dataset: 83381
# Processing image 2104
# Number of data in SVM dataset: 83516
# Number of data in regression dataset: 83516
# Processing image 2105
# Number of data in SVM dataset: 83729
# Number of data in regression dataset: 83729
# Processing image 2106
# Number of data in SVM dataset: 84032
# Number of data in regression dataset: 84032
# Processing image 2107
# Number of data in SVM dataset: 84251
# Number of data in regression dataset: 84251
# Processing image 2108
# Number of data in SVM dataset: 84492
# Number of data in regression dataset: 84492
# Processing image 2109
# Number of data in SVM dataset: 84741
# Number of data in regression dataset: 84741
# Processing image 2110
# Number of data in SVM dataset: 84827
# Number of data in regression dataset: 84827
# Processing image 2111
# Number of data in SVM dataset: 84919
# Number of data in regression dataset: 84919
# Processing image 2112
# Number of data in SVM dataset: 85113
# Number of data in regression dataset: 85113
# Processing image 2113
# Number of data in SVM dataset: 85339
# Number of data in regression dataset: 85339
# Processing image 2114
# Number of data in SVM dataset: 85667
# Number of data in regression dataset: 85667
# Processing image 2115
# Number of data in SVM dataset: 85751
# Number of data in regression dataset: 85751
# Processing image 2116
# Number of data in SVM dataset: 85885
# Number of data in regression dataset: 85885
# Processing image 2117
# Number of data in SVM dataset: 85948
# Number of data in regression dataset: 85948
# Processing image 2118
# Number of data in SVM dataset: 86093
# Number of data in regression dataset: 86093
# Processing image 2119
# Number of data in SVM dataset: 86198
# Number of data in regression dataset: 86198
# Processing image 2120
# Number of data in SVM dataset: 86248
# Number of data in regression dataset: 86248
# Processing image 2121
# Number of data in SVM dataset: 86336
# Number of data in regression dataset: 86336
# Processing image 2122
# Number of data in SVM dataset: 86496
# Number of data in regression dataset: 86496
# Processing image 2123
# Number of data in SVM dataset: 86670
# Number of data in regression dataset: 86670
# Processing image 2124
# Number of data in SVM dataset: 86860
# Number of data in regression dataset: 86860
# Processing image 2125
# Number of data in SVM dataset: 87196
# Number of data in regression dataset: 87196
# Processing image 2126
# Number of data in SVM dataset: 87234
# Number of data in regression dataset: 87234
# Processing image 2127
# Number of data in SVM dataset: 87495
# Number of data in regression dataset: 87495
# Processing image 2128
# Number of data in SVM dataset: 87823
# Number of data in regression dataset: 87823
# Processing image 2129
# Number of data in SVM dataset: 88016
# Number of data in regression dataset: 88016
# Processing image 2130
# Number of data in SVM dataset: 88116
# Number of data in regression dataset: 88116
# Processing image 2131
# Number of data in SVM dataset: 88137
# Number of data in regression dataset: 88137
# Processing image 2132
# Number of data in SVM dataset: 88255
# Number of data in regression dataset: 88255
# Processing image 2133
# Number of data in SVM dataset: 88323
# Number of data in regression dataset: 88323
# Processing image 2134
# Number of data in SVM dataset: 88442
# Number of data in regression dataset: 88442
# Processing image 2135
# Number of data in SVM dataset: 88466
# Number of data in regression dataset: 88466
# Processing image 2136
# Number of data in SVM dataset: 88716
# Number of data in regression dataset: 88716
# Processing image 2137
# Number of data in SVM dataset: 88779
# Number of data in regression dataset: 88779
# Processing image 2138
# Number of data in SVM dataset: 88961
# Number of data in regression dataset: 88961
# Processing image 2139
# Number of data in SVM dataset: 89028
# Number of data in regression dataset: 89028
# Processing image 2140
# Number of data in SVM dataset: 89215
# Number of data in regression dataset: 89215
# Processing image 2141
# Number of data in SVM dataset: 89334
# Number of data in regression dataset: 89334
# Processing image 2142
# Number of data in SVM dataset: 89399
# Number of data in regression dataset: 89399
# Processing image 2143
# Number of data in SVM dataset: 89574
# Number of data in regression dataset: 89574
# Processing image 2144
# Number of data in SVM dataset: 89775
# Number of data in regression dataset: 89775
# Processing image 2145
# Number of data in SVM dataset: 89870
# Number of data in regression dataset: 89870
# Processing image 2146
# Number of data in SVM dataset: 89948
# Number of data in regression dataset: 89948
# Processing image 2147
# Number of data in SVM dataset: 90273
# Number of data in regression dataset: 90273
# Processing image 2148
# Number of data in SVM dataset: 90348
# Number of data in regression dataset: 90348
# Processing image 2149
# Number of data in SVM dataset: 90572
# Number of data in regression dataset: 90572
# Processing image 2150
# Number of data in SVM dataset: 90729
# Number of data in regression dataset: 90729
# Processing image 2151
# Number of data in SVM dataset: 90811
# Number of data in regression dataset: 90811
# Processing image 2152
# Number of data in SVM dataset: 90920
# Number of data in regression dataset: 90920
# Processing image 2153
# Number of data in SVM dataset: 90977
# Number of data in regression dataset: 90977
# Processing image 2154
# Number of data in SVM dataset: 91197
# Number of data in regression dataset: 91197
# Processing image 2155
# Number of data in SVM dataset: 91200
# Number of data in regression dataset: 91200
# Processing image 2156
# Number of data in SVM dataset: 91370
# Number of data in regression dataset: 91370
# Processing image 2157
# Number of data in SVM dataset: 91564
# Number of data in regression dataset: 91564
# Processing image 2158
# Number of data in SVM dataset: 91770
# Number of data in regression dataset: 91770
# Processing image 2159
# Number of data in SVM dataset: 91951
# Number of data in regression dataset: 91951
# Processing image 2160
# Number of data in SVM dataset: 92126
# Number of data in regression dataset: 92126
# Processing image 2161
# Number of data in SVM dataset: 92171
# Number of data in regression dataset: 92171
# Processing image 2162
# Number of data in SVM dataset: 92362
# Number of data in regression dataset: 92362
# Processing image 2163
# Number of data in SVM dataset: 92374
# Number of data in regression dataset: 92374
# Processing image 2164
# Number of data in SVM dataset: 92511
# Number of data in regression dataset: 92511
# Processing image 2165
# Number of data in SVM dataset: 92612
# Number of data in regression dataset: 92612
# Processing image 2166
# Number of data in SVM dataset: 92650
# Number of data in regression dataset: 92650
# Processing image 2167
# Number of data in SVM dataset: 92718
# Number of data in regression dataset: 92718
# Processing image 2168
# Number of data in SVM dataset: 92830
# Number of data in regression dataset: 92830
# Processing image 2169
# Number of data in SVM dataset: 92935
# Number of data in regression dataset: 92935
# Processing image 2170
# Number of data in SVM dataset: 93040
# Number of data in regression dataset: 93040
# Processing image 2171
# Number of data in SVM dataset: 93161
# Number of data in regression dataset: 93161
# Processing image 2172
# Number of data in SVM dataset: 93411
# Number of data in regression dataset: 93411
# Processing image 2173
# Number of data in SVM dataset: 93439
# Number of data in regression dataset: 93439
# Processing image 2174
# Number of data in SVM dataset: 93582
# Number of data in regression dataset: 93582
# Processing image 2175
# Number of data in SVM dataset: 93861
# Number of data in regression dataset: 93861
# Processing image 2176
# Number of data in SVM dataset: 94069
# Number of data in regression dataset: 94069
# Processing image 2177
# Number of data in SVM dataset: 94322
# Number of data in regression dataset: 94322
# Processing image 2178
# Number of data in SVM dataset: 94391
# Number of data in regression dataset: 94391
# Processing image 2179
# Number of data in SVM dataset: 94474
# Number of data in regression dataset: 94474
# Processing image 2180
# Number of data in SVM dataset: 94609
# Number of data in regression dataset: 94609
# Processing image 2181
# Number of data in SVM dataset: 94740
# Number of data in regression dataset: 94740
# Processing image 2182
# Number of data in SVM dataset: 94918
# Number of data in regression dataset: 94918
# Processing image 2183
# Number of data in SVM dataset: 94945
# Number of data in regression dataset: 94945
# Processing image 2184
# Number of data in SVM dataset: 95112
# Number of data in regression dataset: 95112
# Processing image 2185
# Number of data in SVM dataset: 95144
# Number of data in regression dataset: 95144
# Processing image 2186
# Number of data in SVM dataset: 95219
# Number of data in regression dataset: 95219
# Processing image 2187
# Number of data in SVM dataset: 95336
# Number of data in regression dataset: 95336
# Processing image 2188
# Number of data in SVM dataset: 95428
# Number of data in regression dataset: 95428
# Processing image 2189
# Number of data in SVM dataset: 95493
# Number of data in regression dataset: 95493
# Processing image 2190
# Number of data in SVM dataset: 95742
# Number of data in regression dataset: 95742
# Processing image 2191
# Number of data in SVM dataset: 95906
# Number of data in regression dataset: 95906
# Processing image 2192
# Number of data in SVM dataset: 96271
# Number of data in regression dataset: 96271
# Processing image 2193
# Number of data in SVM dataset: 96447
# Number of data in regression dataset: 96447
# Processing image 2194
# Number of data in SVM dataset: 96665
# Number of data in regression dataset: 96665
# Processing image 2195
# Number of data in SVM dataset: 96855
# Number of data in regression dataset: 96855
# Processing image 2196
# Number of data in SVM dataset: 97115
# Number of data in regression dataset: 97115
# Processing image 2197
# Number of data in SVM dataset: 97248
# Number of data in regression dataset: 97248
# Processing image 2198
# Number of data in SVM dataset: 97370
# Number of data in regression dataset: 97370
# Processing image 2199
# Number of data in SVM dataset: 97485
# Number of data in regression dataset: 97485
# Processing image 2200
# Number of data in SVM dataset: 97608
# Number of data in regression dataset: 97608

# %%
# Size in MB of svm_dataset and regression_dataset in memory

print('Size of svm_dataset:', sys.getsizeof(svm_dataset) / 1024 / 1024, 'MB')
print('Size of regression_dataset:', sys.getsizeof(regression_dataset) / 1024 / 1024, 'MB')
# Out:
# Size of svm_dataset: 0.7638778686523438 MB
# Size of regression_dataset: 0.7638778686523438 MB

# %%
with open('svm_dataset_2.pkl', 'rb') as f:
    svm_dataset_one = pickle.load(f)

# %%
# save the svm_dataset and regression_dataset to disk
with open('svm_dataset_1_5.pkl', 'wb') as f:
    pickle.dump(svm_dataset, f)

# with open('regression_dataset.pkl', 'wb') as f:
#     pickle.dump(regression_dataset, f)
