# %%
# %matplotlib inline
import os
import sys
import pickle

from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init

import torchvision
from torchvision import models

import torchvision.transforms as transforms
from torch.utils.data import ConcatDataset
import torch.optim as optim
from torchmetrics import Accuracy
from torchinfo import summary
from torch.utils.tensorboard import SummaryWriter
from torchvision.datasets import VOCDetection

sys.path.append('../../')  
from Object_Detection.RCNN import selective_search
from Object_Detection.RCNN.bbox import calculate_iou
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# Settings 

torch.set_printoptions(precision=3)

# %%
voc_dataset = VOCDetection(root='./data', 
                           year='2012', 
                           image_set='train',
                           download=True, 
                        #    transform=transform
                           )
# Out:
# Using downloaded and verified file: ./data\VOCtrainval_11-May-2012.tar
# Extracting ./data\VOCtrainval_11-May-2012.tar to ./data

# %% [markdown]
# # Load model and its finetuned weights (PASCAL VOC)

# %%
# Step 1: Load the ResNet50 model without pretrained weights
resnet50 = models.resnet50(weights=False)

resnet50.fc = torch.nn.Linear(resnet50.fc.in_features, 20)
# Out:
# m:\ML\ML_regs\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# Step 2: Load your finetuned weights
# Make sure that the path 'voc_finetune_resnet_weights.pth' is correct and accessible
resnet50.load_state_dict(torch.load('resnet50_pascal_voc.pth'))
# Out:
# <All keys matched successfully>

# %%
summary(model=resnet50, input_size=(1, 3, 227, 227), col_width=20,
                  col_names=['input_size', 'output_size', 'num_params', 'trainable'], row_settings=['var_names'], verbose=0)

# %%
class ResNet50Modified(nn.Module):
    def __init__(self, original_model):
        super(ResNet50Modified, self).__init__()
        # Adapt this line if your model was changed differently
        self.features = nn.Sequential(*list(original_model.children())[:-1])  # Typically removes the final fully connected layer and avg pooling layer

    def forward(self, x):
        x = self.features(x)
        return x

# Create the modified model with loaded weights
modified_resnet50 = ResNet50Modified(resnet50)

# Put the model in evaluation mode if you are doing inference or feature extraction
modified_resnet50.eval()

if torch.cuda.is_available():
    modified_resnet50 = modified_resnet50.cuda()

# %%
summary(model=modified_resnet50, input_size=(1, 3, 227, 227), col_width=20,
                  col_names=['input_size', 'output_size', 'num_params', 'trainable'], row_settings=['var_names'], verbose=0)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# ResNet50Modified (ResNet50Modified)           [1, 3, 227, 227]     [1, 2048, 1, 1]      --                   True
# ├─Sequential (features)                       [1, 3, 227, 227]     [1, 2048, 1, 1]      --                   True
# │    └─Conv2d (0)                             [1, 3, 227, 227]     [1, 64, 114, 114]    9,408                True
# │    └─BatchNorm2d (1)                        [1, 64, 114, 114]    [1, 64, 114, 114]    128                  True
# │    └─ReLU (2)                               [1, 64, 114, 114]    [1, 64, 114, 114]    --                   --
# │    └─MaxPool2d (3)                          [1, 64, 114, 114]    [1, 64, 57, 57]      --                   --
# │    └─Sequential (4)                         [1, 64, 57, 57]      [1, 256, 57, 57]     --                   True
# │    │    └─Bottleneck (0)                    [1, 64, 57, 57]      [1, 256, 57, 57]     75,008               True
# │    │    └─Bottleneck (1)                    [1, 256, 57, 57]     [1, 256, 57, 57]     70,400               True
# │    │    └─Bottleneck (2)                    [1, 256, 57, 57]     [1, 256, 57, 57]     70,400               True
# │    └─Sequential (5)                         [1, 256, 57, 57]     [1, 512, 29, 29]     --                   True
# │    │    └─Bottleneck (0)                    [1, 256, 57, 57]     [1, 512, 29, 29]     379,392              True
# │    │    └─Bottleneck (1)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    │    └─Bottleneck (2)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    │    └─Bottleneck (3)                    [1, 512, 29, 29]     [1, 512, 29, 29]     280,064              True
# │    └─Sequential (6)                         [1, 512, 29, 29]     [1, 1024, 15, 15]    --                   True
# │    │    └─Bottleneck (0)                    [1, 512, 29, 29]     [1, 1024, 15, 15]    1,512,448            True
# │    │    └─Bottleneck (1)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (2)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (3)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (4)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    │    └─Bottleneck (5)                    [1, 1024, 15, 15]    [1, 1024, 15, 15]    1,117,184            True
# │    └─Sequential (7)                         [1, 1024, 15, 15]    [1, 2048, 8, 8]      --                   True
# │    │    └─Bottleneck (0)                    [1, 1024, 15, 15]    [1, 2048, 8, 8]      6,039,552            True
# │    │    └─Bottleneck (1)                    [1, 2048, 8, 8]      [1, 2048, 8, 8]      4,462,592            True
# │    │    └─Bottleneck (2)                    [1, 2048, 8, 8]      [1, 2048, 8, 8]      4,462,592            True
# │    └─AdaptiveAvgPool2d (8)                  [1, 2048, 8, 8]      [1, 2048, 1, 1]      --                   --
# =============================================================================================================================
# Total params: 23,508,032
# Trainable params: 23,508,032
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 4.63
# =============================================================================================================================
# Input size (MB): 0.62
# Forward/backward pass size (MB): 191.90
# Params size (MB): 94.03
# Estimated Total Size (MB): 286.55
# =============================================================================================================================

# %% [markdown]
# # Generate features

# %%
voc_dataset
# Out:
# Dataset VOCDetection
#     Number of datapoints: 5717
#     Root location: ./data

# %%
# Single image load from the VOC dataset and in numpy format

image, target = voc_dataset[0]
image_array = np.array(image)

# %%
preprocess = transforms.Compose([
    transforms.Resize((227, 227)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def batch_process_features(model, regions):
    """ Process a batch of regions through the model """
    # Convert list of PIL images to tensor
    regions_tensor = torch.stack([preprocess(region) for region in regions]).cuda()
    
    # Extract features
    with torch.no_grad():
        features = model(regions_tensor)
    return features.cpu().numpy()

gs = selective_search.get_selective_search()

counter, start_index = 0, 0
svm_dataset = []
regression_dataset = []
# Assuming 'voc_dataset' is iterable with (image, annot)
for i in range(start_index, len(voc_dataset)):
    image, annot = voc_dataset[i]
    
    counter += 1
    # Counter for images processed
    print(f'Processing image {counter}')

    # Get proposals and annotations similar to your original code
    image_array = np.array(image)
    selective_search.config(gs, image_array, strategy='q')
    rects = selective_search.get_rects(gs)

    # Prepare annotations
    annotations = []
    for obj in annot['annotation']['object']:
        annotations.append({
            'class': obj['name'],
            'bbox': [int(obj['bndbox']['xmin']), int(obj['bndbox']['ymin']), int(obj['bndbox']['xmax']), int(obj['bndbox']['ymax'])]
        })

    # Collect regions for batch processing
    regions = [image.crop((x1, y1, x2, y2)) for x1, y1, x2, y2 in rects]

    # Process all regions at once in batches
    features = []
    for i in range(0, len(regions), 16):  # batch_size e.g., 32, 64, 128, 256, 512
        batch = regions[i:i + 16]
        batch_features = batch_process_features(modified_resnet50, batch)
        features.extend(batch_features)


    # Calculate IOUs and assign labels after extracting all features
    labels = []
    for proposal, feature in zip(rects, features):
        proposal_iou = {cls['class']: calculate_iou(proposal, cls['bbox']) for cls in annotations}
        best_iou = max(proposal_iou.values())
        if best_iou > 0.5:
            matched_class = max(proposal_iou, key=proposal_iou.get)
            labels.append((proposal, matched_class, 'positive'))
        else:
            labels.append((proposal, None, 'negative'))


    # Prepare datasets for SVM and regression

    for feature, label in zip(features, labels):
        if label[2] == 'positive':
            svm_dataset.append((feature, label[1]))
            ground_truth_bbox = next((item['bbox'] for item in annotations if item['class'] == label[1]), None)
            if ground_truth_bbox:
                tx = ground_truth_bbox[0] - label[0][0]
                ty = ground_truth_bbox[1] - label[0][1]
                tw = ground_truth_bbox[2] - label[0][2]
                th = ground_truth_bbox[3] - label[0][3]
                regression_dataset.append((feature, (tx, ty, tw, th)))
    print(f'Number of data in SVM dataset: {len(svm_dataset)}')
    print(f'Number of data in regression dataset: {len(regression_dataset)}')
    # break after 10 images
    if counter == 500:
        break
# Out:
# Processing image 5201
# Number of data in SVM dataset: 124
# Number of data in regression dataset: 124
# Processing image 5202
# Number of data in SVM dataset: 260
# Number of data in regression dataset: 260
# Processing image 5203
# Number of data in SVM dataset: 559
# Number of data in regression dataset: 559
# Processing image 5204
# Number of data in SVM dataset: 683
# Number of data in regression dataset: 683
# Processing image 5205
# Number of data in SVM dataset: 872
# Number of data in regression dataset: 872
# Processing image 5206
# Number of data in SVM dataset: 1074
# Number of data in regression dataset: 1074
# Processing image 5207
# Number of data in SVM dataset: 1108
# Number of data in regression dataset: 1108
# Processing image 5208
# Number of data in SVM dataset: 1206
# Number of data in regression dataset: 1206
# Processing image 5209
# Number of data in SVM dataset: 1421
# Number of data in regression dataset: 1421
# Processing image 5210
# Number of data in SVM dataset: 1576
# Number of data in regression dataset: 1576
# Processing image 5211
# Number of data in SVM dataset: 1682
# Number of data in regression dataset: 1682
# Processing image 5212
# Number of data in SVM dataset: 1741
# Number of data in regression dataset: 1741
# Processing image 5213
# Number of data in SVM dataset: 1824
# Number of data in regression dataset: 1824
# Processing image 5214
# Number of data in SVM dataset: 2273
# Number of data in regression dataset: 2273
# Processing image 5215
# Number of data in SVM dataset: 2430
# Number of data in regression dataset: 2430
# Processing image 5216
# Number of data in SVM dataset: 2445
# Number of data in regression dataset: 2445
# Processing image 5217
# Number of data in SVM dataset: 2575
# Number of data in regression dataset: 2575
# Processing image 5218
# Number of data in SVM dataset: 2719
# Number of data in regression dataset: 2719
# Processing image 5219
# Number of data in SVM dataset: 2877
# Number of data in regression dataset: 2877
# Processing image 5220
# Number of data in SVM dataset: 2919
# Number of data in regression dataset: 2919
# Processing image 5221
# Number of data in SVM dataset: 3160
# Number of data in regression dataset: 3160
# Processing image 5222
# Number of data in SVM dataset: 3460
# Number of data in regression dataset: 3460
# Processing image 5223
# Number of data in SVM dataset: 3657
# Number of data in regression dataset: 3657
# Processing image 5224
# Number of data in SVM dataset: 3704
# Number of data in regression dataset: 3704
# Processing image 5225
# Number of data in SVM dataset: 3954
# Number of data in regression dataset: 3954
# Processing image 5226
# Number of data in SVM dataset: 4122
# Number of data in regression dataset: 4122
# Processing image 5227
# Number of data in SVM dataset: 4277
# Number of data in regression dataset: 4277
# Processing image 5228
# Number of data in SVM dataset: 4458
# Number of data in regression dataset: 4458
# Processing image 5229
# Number of data in SVM dataset: 4668
# Number of data in regression dataset: 4668
# Processing image 5230
# Number of data in SVM dataset: 4921
# Number of data in regression dataset: 4921
# Processing image 5231
# Number of data in SVM dataset: 4927
# Number of data in regression dataset: 4927
# Processing image 5232
# Number of data in SVM dataset: 5218
# Number of data in regression dataset: 5218
# Processing image 5233
# Number of data in SVM dataset: 5317
# Number of data in regression dataset: 5317
# Processing image 5234
# Number of data in SVM dataset: 5432
# Number of data in regression dataset: 5432
# Processing image 5235
# Number of data in SVM dataset: 5455
# Number of data in regression dataset: 5455
# Processing image 5236
# Number of data in SVM dataset: 5690
# Number of data in regression dataset: 5690
# Processing image 5237
# Number of data in SVM dataset: 5789
# Number of data in regression dataset: 5789
# Processing image 5238
# Number of data in SVM dataset: 6016
# Number of data in regression dataset: 6016
# Processing image 5239
# Number of data in SVM dataset: 6107
# Number of data in regression dataset: 6107
# Processing image 5240
# Number of data in SVM dataset: 6344
# Number of data in regression dataset: 6344
# Processing image 5241
# Number of data in SVM dataset: 6608
# Number of data in regression dataset: 6608
# Processing image 5242
# Number of data in SVM dataset: 6735
# Number of data in regression dataset: 6735
# Processing image 5243
# Number of data in SVM dataset: 6966
# Number of data in regression dataset: 6966
# Processing image 5244
# Number of data in SVM dataset: 7076
# Number of data in regression dataset: 7076
# Processing image 5245
# Number of data in SVM dataset: 7132
# Number of data in regression dataset: 7132
# Processing image 5246
# Number of data in SVM dataset: 7134
# Number of data in regression dataset: 7134
# Processing image 5247
# Number of data in SVM dataset: 7494
# Number of data in regression dataset: 7494
# Processing image 5248
# Number of data in SVM dataset: 7591
# Number of data in regression dataset: 7591
# Processing image 5249
# Number of data in SVM dataset: 7678
# Number of data in regression dataset: 7678
# Processing image 5250
# Number of data in SVM dataset: 7686
# Number of data in regression dataset: 7686
# Processing image 5251
# Number of data in SVM dataset: 7889
# Number of data in regression dataset: 7889
# Processing image 5252
# Number of data in SVM dataset: 7933
# Number of data in regression dataset: 7933
# Processing image 5253
# Number of data in SVM dataset: 8144
# Number of data in regression dataset: 8144
# Processing image 5254
# Number of data in SVM dataset: 8288
# Number of data in regression dataset: 8288
# Processing image 5255
# Number of data in SVM dataset: 8406
# Number of data in regression dataset: 8406
# Processing image 5256
# Number of data in SVM dataset: 8407
# Number of data in regression dataset: 8407
# Processing image 5257
# Number of data in SVM dataset: 8539
# Number of data in regression dataset: 8539
# Processing image 5258
# Number of data in SVM dataset: 8644
# Number of data in regression dataset: 8644
# Processing image 5259
# Number of data in SVM dataset: 8969
# Number of data in regression dataset: 8969
# Processing image 5260
# Number of data in SVM dataset: 9129
# Number of data in regression dataset: 9129
# Processing image 5261
# Number of data in SVM dataset: 9182
# Number of data in regression dataset: 9182
# Processing image 5262
# Number of data in SVM dataset: 9302
# Number of data in regression dataset: 9302
# Processing image 5263
# Number of data in SVM dataset: 9320
# Number of data in regression dataset: 9320
# Processing image 5264
# Number of data in SVM dataset: 9408
# Number of data in regression dataset: 9408
# Processing image 5265
# Number of data in SVM dataset: 9438
# Number of data in regression dataset: 9438
# Processing image 5266
# Number of data in SVM dataset: 9522
# Number of data in regression dataset: 9522
# Processing image 5267
# Number of data in SVM dataset: 9683
# Number of data in regression dataset: 9683
# Processing image 5268
# Number of data in SVM dataset: 9976
# Number of data in regression dataset: 9976
# Processing image 5269
# Number of data in SVM dataset: 10043
# Number of data in regression dataset: 10043
# Processing image 5270
# Number of data in SVM dataset: 10221
# Number of data in regression dataset: 10221
# Processing image 5271
# Number of data in SVM dataset: 10628
# Number of data in regression dataset: 10628
# Processing image 5272
# Number of data in SVM dataset: 10839
# Number of data in regression dataset: 10839
# Processing image 5273
# Number of data in SVM dataset: 11124
# Number of data in regression dataset: 11124
# Processing image 5274
# Number of data in SVM dataset: 11220
# Number of data in regression dataset: 11220
# Processing image 5275
# Number of data in SVM dataset: 11350
# Number of data in regression dataset: 11350
# Processing image 5276
# Number of data in SVM dataset: 11423
# Number of data in regression dataset: 11423
# Processing image 5277
# Number of data in SVM dataset: 11424
# Number of data in regression dataset: 11424
# Processing image 5278
# Number of data in SVM dataset: 11559
# Number of data in regression dataset: 11559
# Processing image 5279
# Number of data in SVM dataset: 11730
# Number of data in regression dataset: 11730
# Processing image 5280
# Number of data in SVM dataset: 11899
# Number of data in regression dataset: 11899
# Processing image 5281
# Number of data in SVM dataset: 11940
# Number of data in regression dataset: 11940
# Processing image 5282
# Number of data in SVM dataset: 12000
# Number of data in regression dataset: 12000
# Processing image 5283
# Number of data in SVM dataset: 12262
# Number of data in regression dataset: 12262
# Processing image 5284
# Number of data in SVM dataset: 12265
# Number of data in regression dataset: 12265
# Processing image 5285
# Number of data in SVM dataset: 12383
# Number of data in regression dataset: 12383
# Processing image 5286
# Number of data in SVM dataset: 12413
# Number of data in regression dataset: 12413
# Processing image 5287
# Number of data in SVM dataset: 12619
# Number of data in regression dataset: 12619
# Processing image 5288
# Number of data in SVM dataset: 12764
# Number of data in regression dataset: 12764
# Processing image 5289
# Number of data in SVM dataset: 13129
# Number of data in regression dataset: 13129
# Processing image 5290
# Number of data in SVM dataset: 13304
# Number of data in regression dataset: 13304
# Processing image 5291
# Number of data in SVM dataset: 13497
# Number of data in regression dataset: 13497
# Processing image 5292
# Number of data in SVM dataset: 13564
# Number of data in regression dataset: 13564
# Processing image 5293
# Number of data in SVM dataset: 13581
# Number of data in regression dataset: 13581
# Processing image 5294
# Number of data in SVM dataset: 13808
# Number of data in regression dataset: 13808
# Processing image 5295
# Number of data in SVM dataset: 13889
# Number of data in regression dataset: 13889
# Processing image 5296
# Number of data in SVM dataset: 14018
# Number of data in regression dataset: 14018
# Processing image 5297
# Number of data in SVM dataset: 14162
# Number of data in regression dataset: 14162
# Processing image 5298
# Number of data in SVM dataset: 14635
# Number of data in regression dataset: 14635
# Processing image 5299
# Number of data in SVM dataset: 14756
# Number of data in regression dataset: 14756
# Processing image 5300
# Number of data in SVM dataset: 14899
# Number of data in regression dataset: 14899
# Processing image 5301
# Number of data in SVM dataset: 15236
# Number of data in regression dataset: 15236
# Processing image 5302
# Number of data in SVM dataset: 15507
# Number of data in regression dataset: 15507
# Processing image 5303
# Number of data in SVM dataset: 15531
# Number of data in regression dataset: 15531
# Processing image 5304
# Number of data in SVM dataset: 15578
# Number of data in regression dataset: 15578
# Processing image 5305
# Number of data in SVM dataset: 15778
# Number of data in regression dataset: 15778
# Processing image 5306
# Number of data in SVM dataset: 16009
# Number of data in regression dataset: 16009
# Processing image 5307
# Number of data in SVM dataset: 16456
# Number of data in regression dataset: 16456
# Processing image 5308
# Number of data in SVM dataset: 16595
# Number of data in regression dataset: 16595
# Processing image 5309
# Number of data in SVM dataset: 16727
# Number of data in regression dataset: 16727
# Processing image 5310
# Number of data in SVM dataset: 16918
# Number of data in regression dataset: 16918
# Processing image 5311
# Number of data in SVM dataset: 17231
# Number of data in regression dataset: 17231
# Processing image 5312
# Number of data in SVM dataset: 17274
# Number of data in regression dataset: 17274
# Processing image 5313
# Number of data in SVM dataset: 17478
# Number of data in regression dataset: 17478
# Processing image 5314
# Number of data in SVM dataset: 17811
# Number of data in regression dataset: 17811
# Processing image 5315
# Number of data in SVM dataset: 17994
# Number of data in regression dataset: 17994
# Processing image 5316
# Number of data in SVM dataset: 18073
# Number of data in regression dataset: 18073
# Processing image 5317
# Number of data in SVM dataset: 18538
# Number of data in regression dataset: 18538
# Processing image 5318
# Number of data in SVM dataset: 18789
# Number of data in regression dataset: 18789
# Processing image 5319
# Number of data in SVM dataset: 18966
# Number of data in regression dataset: 18966
# Processing image 5320
# Number of data in SVM dataset: 18968
# Number of data in regression dataset: 18968
# Processing image 5321
# Number of data in SVM dataset: 19120
# Number of data in regression dataset: 19120
# Processing image 5322
# Number of data in SVM dataset: 19320
# Number of data in regression dataset: 19320
# Processing image 5323
# Number of data in SVM dataset: 19607
# Number of data in regression dataset: 19607
# Processing image 5324
# Number of data in SVM dataset: 19781
# Number of data in regression dataset: 19781
# Processing image 5325
# Number of data in SVM dataset: 19825
# Number of data in regression dataset: 19825
# Processing image 5326
# Number of data in SVM dataset: 19837
# Number of data in regression dataset: 19837
# Processing image 5327
# Number of data in SVM dataset: 20038
# Number of data in regression dataset: 20038
# Processing image 5328
# Number of data in SVM dataset: 20276
# Number of data in regression dataset: 20276
# Processing image 5329
# Number of data in SVM dataset: 20495
# Number of data in regression dataset: 20495
# Processing image 5330
# Number of data in SVM dataset: 20523
# Number of data in regression dataset: 20523
# Processing image 5331
# Number of data in SVM dataset: 20683
# Number of data in regression dataset: 20683
# Processing image 5332
# Number of data in SVM dataset: 20904
# Number of data in regression dataset: 20904
# Processing image 5333
# Number of data in SVM dataset: 21043
# Number of data in regression dataset: 21043
# Processing image 5334
# Number of data in SVM dataset: 21272
# Number of data in regression dataset: 21272
# Processing image 5335
# Number of data in SVM dataset: 21571
# Number of data in regression dataset: 21571
# Processing image 5336
# Number of data in SVM dataset: 21651
# Number of data in regression dataset: 21651
# Processing image 5337
# Number of data in SVM dataset: 21660
# Number of data in regression dataset: 21660
# Processing image 5338
# Number of data in SVM dataset: 21873
# Number of data in regression dataset: 21873
# Processing image 5339
# Number of data in SVM dataset: 21889
# Number of data in regression dataset: 21889
# Processing image 5340
# Number of data in SVM dataset: 22103
# Number of data in regression dataset: 22103
# Processing image 5341
# Number of data in SVM dataset: 22235
# Number of data in regression dataset: 22235
# Processing image 5342
# Number of data in SVM dataset: 22383
# Number of data in regression dataset: 22383
# Processing image 5343
# Number of data in SVM dataset: 22737
# Number of data in regression dataset: 22737
# Processing image 5344
# Number of data in SVM dataset: 22883
# Number of data in regression dataset: 22883
# Processing image 5345
# Number of data in SVM dataset: 23134
# Number of data in regression dataset: 23134
# Processing image 5346
# Number of data in SVM dataset: 23364
# Number of data in regression dataset: 23364
# Processing image 5347
# Number of data in SVM dataset: 23660
# Number of data in regression dataset: 23660
# Processing image 5348
# Number of data in SVM dataset: 23687
# Number of data in regression dataset: 23687
# Processing image 5349
# Number of data in SVM dataset: 23763
# Number of data in regression dataset: 23763
# Processing image 5350
# Number of data in SVM dataset: 23880
# Number of data in regression dataset: 23880
# Processing image 5351
# Number of data in SVM dataset: 23992
# Number of data in regression dataset: 23992
# Processing image 5352
# Number of data in SVM dataset: 23992
# Number of data in regression dataset: 23992
# Processing image 5353
# Number of data in SVM dataset: 24120
# Number of data in regression dataset: 24120
# Processing image 5354
# Number of data in SVM dataset: 24171
# Number of data in regression dataset: 24171
# Processing image 5355
# Number of data in SVM dataset: 24444
# Number of data in regression dataset: 24444
# Processing image 5356
# Number of data in SVM dataset: 24629
# Number of data in regression dataset: 24629
# Processing image 5357
# Number of data in SVM dataset: 24727
# Number of data in regression dataset: 24727
# Processing image 5358
# Number of data in SVM dataset: 24855
# Number of data in regression dataset: 24855
# Processing image 5359
# Number of data in SVM dataset: 24996
# Number of data in regression dataset: 24996
# Processing image 5360
# Number of data in SVM dataset: 25020
# Number of data in regression dataset: 25020
# Processing image 5361
# Number of data in SVM dataset: 25094
# Number of data in regression dataset: 25094
# Processing image 5362
# Number of data in SVM dataset: 25163
# Number of data in regression dataset: 25163
# Processing image 5363
# Number of data in SVM dataset: 25495
# Number of data in regression dataset: 25495
# Processing image 5364
# Number of data in SVM dataset: 25697
# Number of data in regression dataset: 25697
# Processing image 5365
# Number of data in SVM dataset: 25834
# Number of data in regression dataset: 25834
# Processing image 5366
# Number of data in SVM dataset: 26129
# Number of data in regression dataset: 26129
# Processing image 5367
# Number of data in SVM dataset: 26319
# Number of data in regression dataset: 26319
# Processing image 5368
# Number of data in SVM dataset: 26493
# Number of data in regression dataset: 26493
# Processing image 5369
# Number of data in SVM dataset: 26802
# Number of data in regression dataset: 26802
# Processing image 5370
# Number of data in SVM dataset: 26920
# Number of data in regression dataset: 26920
# Processing image 5371
# Number of data in SVM dataset: 26922
# Number of data in regression dataset: 26922
# Processing image 5372
# Number of data in SVM dataset: 26941
# Number of data in regression dataset: 26941
# Processing image 5373
# Number of data in SVM dataset: 27124
# Number of data in regression dataset: 27124
# Processing image 5374
# Number of data in SVM dataset: 27182
# Number of data in regression dataset: 27182
# Processing image 5375
# Number of data in SVM dataset: 27346
# Number of data in regression dataset: 27346
# Processing image 5376
# Number of data in SVM dataset: 27388
# Number of data in regression dataset: 27388
# Processing image 5377
# Number of data in SVM dataset: 27635
# Number of data in regression dataset: 27635
# Processing image 5378
# Number of data in SVM dataset: 27957
# Number of data in regression dataset: 27957
# Processing image 5379
# Number of data in SVM dataset: 28230
# Number of data in regression dataset: 28230
# Processing image 5380
# Number of data in SVM dataset: 28514
# Number of data in regression dataset: 28514
# Processing image 5381
# Number of data in SVM dataset: 28630
# Number of data in regression dataset: 28630
# Processing image 5382
# Number of data in SVM dataset: 28640
# Number of data in regression dataset: 28640
# Processing image 5383
# Number of data in SVM dataset: 28802
# Number of data in regression dataset: 28802
# Processing image 5384
# Number of data in SVM dataset: 28853
# Number of data in regression dataset: 28853
# Processing image 5385
# Number of data in SVM dataset: 29041
# Number of data in regression dataset: 29041
# Processing image 5386
# Number of data in SVM dataset: 29100
# Number of data in regression dataset: 29100
# Processing image 5387
# Number of data in SVM dataset: 29311
# Number of data in regression dataset: 29311
# Processing image 5388
# Number of data in SVM dataset: 29431
# Number of data in regression dataset: 29431
# Processing image 5389
# Number of data in SVM dataset: 29490
# Number of data in regression dataset: 29490
# Processing image 5390
# Number of data in SVM dataset: 29774
# Number of data in regression dataset: 29774
# Processing image 5391
# Number of data in SVM dataset: 29884
# Number of data in regression dataset: 29884
# Processing image 5392
# Number of data in SVM dataset: 29992
# Number of data in regression dataset: 29992
# Processing image 5393
# Number of data in SVM dataset: 30044
# Number of data in regression dataset: 30044
# Processing image 5394
# Number of data in SVM dataset: 30068
# Number of data in regression dataset: 30068
# Processing image 5395
# Number of data in SVM dataset: 30183
# Number of data in regression dataset: 30183
# Processing image 5396
# Number of data in SVM dataset: 30437
# Number of data in regression dataset: 30437
# Processing image 5397
# Number of data in SVM dataset: 30583
# Number of data in regression dataset: 30583
# Processing image 5398
# Number of data in SVM dataset: 30631
# Number of data in regression dataset: 30631
# Processing image 5399
# Number of data in SVM dataset: 30917
# Number of data in regression dataset: 30917
# Processing image 5400
# Number of data in SVM dataset: 31191
# Number of data in regression dataset: 31191
# Processing image 5401
# Number of data in SVM dataset: 31294
# Number of data in regression dataset: 31294
# Processing image 5402
# Number of data in SVM dataset: 31406
# Number of data in regression dataset: 31406
# Processing image 5403
# Number of data in SVM dataset: 31528
# Number of data in regression dataset: 31528
# Processing image 5404
# Number of data in SVM dataset: 31694
# Number of data in regression dataset: 31694
# Processing image 5405
# Number of data in SVM dataset: 31819
# Number of data in regression dataset: 31819
# Processing image 5406
# Number of data in SVM dataset: 31833
# Number of data in regression dataset: 31833
# Processing image 5407
# Number of data in SVM dataset: 31963
# Number of data in regression dataset: 31963
# Processing image 5408
# Number of data in SVM dataset: 32156
# Number of data in regression dataset: 32156
# Processing image 5409
# Number of data in SVM dataset: 32259
# Number of data in regression dataset: 32259
# Processing image 5410
# Number of data in SVM dataset: 32279
# Number of data in regression dataset: 32279
# Processing image 5411
# Number of data in SVM dataset: 32416
# Number of data in regression dataset: 32416
# Processing image 5412
# Number of data in SVM dataset: 32423
# Number of data in regression dataset: 32423
# Processing image 5413
# Number of data in SVM dataset: 32515
# Number of data in regression dataset: 32515
# Processing image 5414
# Number of data in SVM dataset: 32690
# Number of data in regression dataset: 32690
# Processing image 5415
# Number of data in SVM dataset: 32754
# Number of data in regression dataset: 32754
# Processing image 5416
# Number of data in SVM dataset: 32871
# Number of data in regression dataset: 32871
# Processing image 5417
# Number of data in SVM dataset: 33006
# Number of data in regression dataset: 33006
# Processing image 5418
# Number of data in SVM dataset: 33141
# Number of data in regression dataset: 33141
# Processing image 5419
# Number of data in SVM dataset: 33265
# Number of data in regression dataset: 33265
# Processing image 5420
# Number of data in SVM dataset: 33555
# Number of data in regression dataset: 33555
# Processing image 5421
# Number of data in SVM dataset: 33647
# Number of data in regression dataset: 33647
# Processing image 5422
# Number of data in SVM dataset: 33740
# Number of data in regression dataset: 33740
# Processing image 5423
# Number of data in SVM dataset: 33809
# Number of data in regression dataset: 33809
# Processing image 5424
# Number of data in SVM dataset: 34262
# Number of data in regression dataset: 34262
# Processing image 5425
# Number of data in SVM dataset: 34507
# Number of data in regression dataset: 34507
# Processing image 5426
# Number of data in SVM dataset: 34744
# Number of data in regression dataset: 34744
# Processing image 5427
# Number of data in SVM dataset: 34814
# Number of data in regression dataset: 34814
# Processing image 5428
# Number of data in SVM dataset: 34995
# Number of data in regression dataset: 34995
# Processing image 5429
# Number of data in SVM dataset: 35011
# Number of data in regression dataset: 35011
# Processing image 5430
# Number of data in SVM dataset: 35154
# Number of data in regression dataset: 35154
# Processing image 5431
# Number of data in SVM dataset: 35299
# Number of data in regression dataset: 35299
# Processing image 5432
# Number of data in SVM dataset: 35299
# Number of data in regression dataset: 35299
# Processing image 5433
# Number of data in SVM dataset: 35529
# Number of data in regression dataset: 35529
# Processing image 5434
# Number of data in SVM dataset: 35557
# Number of data in regression dataset: 35557
# Processing image 5435
# Number of data in SVM dataset: 35772
# Number of data in regression dataset: 35772
# Processing image 5436
# Number of data in SVM dataset: 36002
# Number of data in regression dataset: 36002
# Processing image 5437
# Number of data in SVM dataset: 36063
# Number of data in regression dataset: 36063
# Processing image 5438
# Number of data in SVM dataset: 36213
# Number of data in regression dataset: 36213
# Processing image 5439
# Number of data in SVM dataset: 36283
# Number of data in regression dataset: 36283
# Processing image 5440
# Number of data in SVM dataset: 36467
# Number of data in regression dataset: 36467
# Processing image 5441
# Number of data in SVM dataset: 36552
# Number of data in regression dataset: 36552
# Processing image 5442
# Number of data in SVM dataset: 36791
# Number of data in regression dataset: 36791
# Processing image 5443
# Number of data in SVM dataset: 36841
# Number of data in regression dataset: 36841
# Processing image 5444
# Number of data in SVM dataset: 37239
# Number of data in regression dataset: 37239
# Processing image 5445
# Number of data in SVM dataset: 37488
# Number of data in regression dataset: 37488
# Processing image 5446
# Number of data in SVM dataset: 37516
# Number of data in regression dataset: 37516
# Processing image 5447
# Number of data in SVM dataset: 37796
# Number of data in regression dataset: 37796
# Processing image 5448
# Number of data in SVM dataset: 37964
# Number of data in regression dataset: 37964
# Processing image 5449
# Number of data in SVM dataset: 38398
# Number of data in regression dataset: 38398
# Processing image 5450
# Number of data in SVM dataset: 38459
# Number of data in regression dataset: 38459
# Processing image 5451
# Number of data in SVM dataset: 38495
# Number of data in regression dataset: 38495
# Processing image 5452
# Number of data in SVM dataset: 38870
# Number of data in regression dataset: 38870
# Processing image 5453
# Number of data in SVM dataset: 38907
# Number of data in regression dataset: 38907
# Processing image 5454
# Number of data in SVM dataset: 38909
# Number of data in regression dataset: 38909
# Processing image 5455
# Number of data in SVM dataset: 38909
# Number of data in regression dataset: 38909
# Processing image 5456
# Number of data in SVM dataset: 39066
# Number of data in regression dataset: 39066
# Processing image 5457
# Number of data in SVM dataset: 39224
# Number of data in regression dataset: 39224
# Processing image 5458
# Number of data in SVM dataset: 39538
# Number of data in regression dataset: 39538
# Processing image 5459
# Number of data in SVM dataset: 39552
# Number of data in regression dataset: 39552
# Processing image 5460
# Number of data in SVM dataset: 39626
# Number of data in regression dataset: 39626
# Processing image 5461
# Number of data in SVM dataset: 39691
# Number of data in regression dataset: 39691
# Processing image 5462
# Number of data in SVM dataset: 39861
# Number of data in regression dataset: 39861
# Processing image 5463
# Number of data in SVM dataset: 39879
# Number of data in regression dataset: 39879
# Processing image 5464
# Number of data in SVM dataset: 39998
# Number of data in regression dataset: 39998
# Processing image 5465
# Number of data in SVM dataset: 40080
# Number of data in regression dataset: 40080
# Processing image 5466
# Number of data in SVM dataset: 40350
# Number of data in regression dataset: 40350
# Processing image 5467
# Number of data in SVM dataset: 40510
# Number of data in regression dataset: 40510
# Processing image 5468
# Number of data in SVM dataset: 40516
# Number of data in regression dataset: 40516
# Processing image 5469
# Number of data in SVM dataset: 40579
# Number of data in regression dataset: 40579
# Processing image 5470
# Number of data in SVM dataset: 40707
# Number of data in regression dataset: 40707
# Processing image 5471
# Number of data in SVM dataset: 40916
# Number of data in regression dataset: 40916
# Processing image 5472
# Number of data in SVM dataset: 41016
# Number of data in regression dataset: 41016
# Processing image 5473
# Number of data in SVM dataset: 41091
# Number of data in regression dataset: 41091
# Processing image 5474
# Number of data in SVM dataset: 41222
# Number of data in regression dataset: 41222
# Processing image 5475
# Number of data in SVM dataset: 41483
# Number of data in regression dataset: 41483
# Processing image 5476
# Number of data in SVM dataset: 41539
# Number of data in regression dataset: 41539
# Processing image 5477
# Number of data in SVM dataset: 41606
# Number of data in regression dataset: 41606
# Processing image 5478
# Number of data in SVM dataset: 41863
# Number of data in regression dataset: 41863
# Processing image 5479
# Number of data in SVM dataset: 42059
# Number of data in regression dataset: 42059
# Processing image 5480
# Number of data in SVM dataset: 42241
# Number of data in regression dataset: 42241
# Processing image 5481
# Number of data in SVM dataset: 42689
# Number of data in regression dataset: 42689
# Processing image 5482
# Number of data in SVM dataset: 42835
# Number of data in regression dataset: 42835
# Processing image 5483
# Number of data in SVM dataset: 42890
# Number of data in regression dataset: 42890
# Processing image 5484
# Number of data in SVM dataset: 43337
# Number of data in regression dataset: 43337
# Processing image 5485
# Number of data in SVM dataset: 43458
# Number of data in regression dataset: 43458
# Processing image 5486
# Number of data in SVM dataset: 43514
# Number of data in regression dataset: 43514
# Processing image 5487
# Number of data in SVM dataset: 43904
# Number of data in regression dataset: 43904
# Processing image 5488
# Number of data in SVM dataset: 44412
# Number of data in regression dataset: 44412
# Processing image 5489
# Number of data in SVM dataset: 44519
# Number of data in regression dataset: 44519
# Processing image 5490
# Number of data in SVM dataset: 44600
# Number of data in regression dataset: 44600
# Processing image 5491
# Number of data in SVM dataset: 44870
# Number of data in regression dataset: 44870
# Processing image 5492
# Number of data in SVM dataset: 44976
# Number of data in regression dataset: 44976
# Processing image 5493
# Number of data in SVM dataset: 44994
# Number of data in regression dataset: 44994
# Processing image 5494
# Number of data in SVM dataset: 45203
# Number of data in regression dataset: 45203
# Processing image 5495
# Number of data in SVM dataset: 45421
# Number of data in regression dataset: 45421
# Processing image 5496
# Number of data in SVM dataset: 45554
# Number of data in regression dataset: 45554
# Processing image 5497
# Number of data in SVM dataset: 45602
# Number of data in regression dataset: 45602
# Processing image 5498
# Number of data in SVM dataset: 45724
# Number of data in regression dataset: 45724
# Processing image 5499
# Number of data in SVM dataset: 45876
# Number of data in regression dataset: 45876
# Processing image 5500
# Number of data in SVM dataset: 46011
# Number of data in regression dataset: 46011
# Processing image 5501
# Number of data in SVM dataset: 46240
# Number of data in regression dataset: 46240
# Processing image 5502
# Number of data in SVM dataset: 46268
# Number of data in regression dataset: 46268
# Processing image 5503
# Number of data in SVM dataset: 46369
# Number of data in regression dataset: 46369
# Processing image 5504
# Number of data in SVM dataset: 46500
# Number of data in regression dataset: 46500
# Processing image 5505
# Number of data in SVM dataset: 46635
# Number of data in regression dataset: 46635
# Processing image 5506
# Number of data in SVM dataset: 46770
# Number of data in regression dataset: 46770
# Processing image 5507
# Number of data in SVM dataset: 47033
# Number of data in regression dataset: 47033
# Processing image 5508
# Number of data in SVM dataset: 47173
# Number of data in regression dataset: 47173
# Processing image 5509
# Number of data in SVM dataset: 47525
# Number of data in regression dataset: 47525
# Processing image 5510
# Number of data in SVM dataset: 47643
# Number of data in regression dataset: 47643
# Processing image 5511
# Number of data in SVM dataset: 47865
# Number of data in regression dataset: 47865
# Processing image 5512
# Number of data in SVM dataset: 47880
# Number of data in regression dataset: 47880
# Processing image 5513
# Number of data in SVM dataset: 48199
# Number of data in regression dataset: 48199
# Processing image 5514
# Number of data in SVM dataset: 48346
# Number of data in regression dataset: 48346
# Processing image 5515
# Number of data in SVM dataset: 48421
# Number of data in regression dataset: 48421
# Processing image 5516
# Number of data in SVM dataset: 48525
# Number of data in regression dataset: 48525
# Processing image 5517
# Number of data in SVM dataset: 48661
# Number of data in regression dataset: 48661
# Processing image 5518
# Number of data in SVM dataset: 48715
# Number of data in regression dataset: 48715
# Processing image 5519
# Number of data in SVM dataset: 49146
# Number of data in regression dataset: 49146
# Processing image 5520
# Number of data in SVM dataset: 49183
# Number of data in regression dataset: 49183
# Processing image 5521
# Number of data in SVM dataset: 49235
# Number of data in regression dataset: 49235
# Processing image 5522
# Number of data in SVM dataset: 49520
# Number of data in regression dataset: 49520
# Processing image 5523
# Number of data in SVM dataset: 49677
# Number of data in regression dataset: 49677
# Processing image 5524
# Number of data in SVM dataset: 50007
# Number of data in regression dataset: 50007
# Processing image 5525
# Number of data in SVM dataset: 50272
# Number of data in regression dataset: 50272
# Processing image 5526
# Number of data in SVM dataset: 50400
# Number of data in regression dataset: 50400
# Processing image 5527
# Number of data in SVM dataset: 50650
# Number of data in regression dataset: 50650
# Processing image 5528
# Number of data in SVM dataset: 50782
# Number of data in regression dataset: 50782
# Processing image 5529
# Number of data in SVM dataset: 50954
# Number of data in regression dataset: 50954
# Processing image 5530
# Number of data in SVM dataset: 51157
# Number of data in regression dataset: 51157
# Processing image 5531
# Number of data in SVM dataset: 51381
# Number of data in regression dataset: 51381
# Processing image 5532
# Number of data in SVM dataset: 51644
# Number of data in regression dataset: 51644
# Processing image 5533
# Number of data in SVM dataset: 51665
# Number of data in regression dataset: 51665
# Processing image 5534
# Number of data in SVM dataset: 51694
# Number of data in regression dataset: 51694
# Processing image 5535
# Number of data in SVM dataset: 51800
# Number of data in regression dataset: 51800
# Processing image 5536
# Number of data in SVM dataset: 51934
# Number of data in regression dataset: 51934
# Processing image 5537
# Number of data in SVM dataset: 52081
# Number of data in regression dataset: 52081
# Processing image 5538
# Number of data in SVM dataset: 52083
# Number of data in regression dataset: 52083
# Processing image 5539
# Number of data in SVM dataset: 52322
# Number of data in regression dataset: 52322
# Processing image 5540
# Number of data in SVM dataset: 52427
# Number of data in regression dataset: 52427
# Processing image 5541
# Number of data in SVM dataset: 52775
# Number of data in regression dataset: 52775
# Processing image 5542
# Number of data in SVM dataset: 52907
# Number of data in regression dataset: 52907
# Processing image 5543
# Number of data in SVM dataset: 53132
# Number of data in regression dataset: 53132
# Processing image 5544
# Number of data in SVM dataset: 53132
# Number of data in regression dataset: 53132
# Processing image 5545
# Number of data in SVM dataset: 53182
# Number of data in regression dataset: 53182
# Processing image 5546
# Number of data in SVM dataset: 53201
# Number of data in regression dataset: 53201
# Processing image 5547
# Number of data in SVM dataset: 53452
# Number of data in regression dataset: 53452
# Processing image 5548
# Number of data in SVM dataset: 53579
# Number of data in regression dataset: 53579
# Processing image 5549
# Number of data in SVM dataset: 53648
# Number of data in regression dataset: 53648
# Processing image 5550
# Number of data in SVM dataset: 53689
# Number of data in regression dataset: 53689
# Processing image 5551
# Number of data in SVM dataset: 53837
# Number of data in regression dataset: 53837
# Processing image 5552
# Number of data in SVM dataset: 54020
# Number of data in regression dataset: 54020
# Processing image 5553
# Number of data in SVM dataset: 54028
# Number of data in regression dataset: 54028
# Processing image 5554
# Number of data in SVM dataset: 54113
# Number of data in regression dataset: 54113
# Processing image 5555
# Number of data in SVM dataset: 54135
# Number of data in regression dataset: 54135
# Processing image 5556
# Number of data in SVM dataset: 54286
# Number of data in regression dataset: 54286
# Processing image 5557
# Number of data in SVM dataset: 54407
# Number of data in regression dataset: 54407
# Processing image 5558
# Number of data in SVM dataset: 54599
# Number of data in regression dataset: 54599
# Processing image 5559
# Number of data in SVM dataset: 54698
# Number of data in regression dataset: 54698
# Processing image 5560
# Number of data in SVM dataset: 55007
# Number of data in regression dataset: 55007
# Processing image 5561
# Number of data in SVM dataset: 55086
# Number of data in regression dataset: 55086
# Processing image 5562
# Number of data in SVM dataset: 55119
# Number of data in regression dataset: 55119
# Processing image 5563
# Number of data in SVM dataset: 55404
# Number of data in regression dataset: 55404
# Processing image 5564
# Number of data in SVM dataset: 55658
# Number of data in regression dataset: 55658
# Processing image 5565
# Number of data in SVM dataset: 55705
# Number of data in regression dataset: 55705
# Processing image 5566
# Number of data in SVM dataset: 55734
# Number of data in regression dataset: 55734
# Processing image 5567
# Number of data in SVM dataset: 55947
# Number of data in regression dataset: 55947
# Processing image 5568
# Number of data in SVM dataset: 55956
# Number of data in regression dataset: 55956
# Processing image 5569
# Number of data in SVM dataset: 56021
# Number of data in regression dataset: 56021
# Processing image 5570
# Number of data in SVM dataset: 56204
# Number of data in regression dataset: 56204
# Processing image 5571
# Number of data in SVM dataset: 56365
# Number of data in regression dataset: 56365
# Processing image 5572
# Number of data in SVM dataset: 56539
# Number of data in regression dataset: 56539
# Processing image 5573
# Number of data in SVM dataset: 56692
# Number of data in regression dataset: 56692
# Processing image 5574
# Number of data in SVM dataset: 56920
# Number of data in regression dataset: 56920
# Processing image 5575
# Number of data in SVM dataset: 56933
# Number of data in regression dataset: 56933
# Processing image 5576
# Number of data in SVM dataset: 57214
# Number of data in regression dataset: 57214
# Processing image 5577
# Number of data in SVM dataset: 57228
# Number of data in regression dataset: 57228
# Processing image 5578
# Number of data in SVM dataset: 57239
# Number of data in regression dataset: 57239
# Processing image 5579
# Number of data in SVM dataset: 57257
# Number of data in regression dataset: 57257
# Processing image 5580
# Number of data in SVM dataset: 57419
# Number of data in regression dataset: 57419
# Processing image 5581
# Number of data in SVM dataset: 57524
# Number of data in regression dataset: 57524
# Processing image 5582
# Number of data in SVM dataset: 57530
# Number of data in regression dataset: 57530
# Processing image 5583
# Number of data in SVM dataset: 57684
# Number of data in regression dataset: 57684
# Processing image 5584
# Number of data in SVM dataset: 57816
# Number of data in regression dataset: 57816
# Processing image 5585
# Number of data in SVM dataset: 57993
# Number of data in regression dataset: 57993
# Processing image 5586
# Number of data in SVM dataset: 58152
# Number of data in regression dataset: 58152
# Processing image 5587
# Number of data in SVM dataset: 58241
# Number of data in regression dataset: 58241
# Processing image 5588
# Number of data in SVM dataset: 58349
# Number of data in regression dataset: 58349
# Processing image 5589
# Number of data in SVM dataset: 58418
# Number of data in regression dataset: 58418
# Processing image 5590
# Number of data in SVM dataset: 58480
# Number of data in regression dataset: 58480
# Processing image 5591
# Number of data in SVM dataset: 58523
# Number of data in regression dataset: 58523
# Processing image 5592
# Number of data in SVM dataset: 58698
# Number of data in regression dataset: 58698
# Processing image 5593
# Number of data in SVM dataset: 58798
# Number of data in regression dataset: 58798
# Processing image 5594
# Number of data in SVM dataset: 58885
# Number of data in regression dataset: 58885
# Processing image 5595
# Number of data in SVM dataset: 59038
# Number of data in regression dataset: 59038
# Processing image 5596
# Number of data in SVM dataset: 59117
# Number of data in regression dataset: 59117
# Processing image 5597
# Number of data in SVM dataset: 59278
# Number of data in regression dataset: 59278
# Processing image 5598
# Number of data in SVM dataset: 59329
# Number of data in regression dataset: 59329
# Processing image 5599
# Number of data in SVM dataset: 59441
# Number of data in regression dataset: 59441
# Processing image 5600
# Number of data in SVM dataset: 59516
# Number of data in regression dataset: 59516
# Processing image 5601
# Number of data in SVM dataset: 59528
# Number of data in regression dataset: 59528
# Processing image 5602
# Number of data in SVM dataset: 59720
# Number of data in regression dataset: 59720
# Processing image 5603
# Number of data in SVM dataset: 59752
# Number of data in regression dataset: 59752
# Processing image 5604
# Number of data in SVM dataset: 59986
# Number of data in regression dataset: 59986
# Processing image 5605
# Number of data in SVM dataset: 60000
# Number of data in regression dataset: 60000
# Processing image 5606
# Number of data in SVM dataset: 60111
# Number of data in regression dataset: 60111
# Processing image 5607
# Number of data in SVM dataset: 60491
# Number of data in regression dataset: 60491
# Processing image 5608
# Number of data in SVM dataset: 60515
# Number of data in regression dataset: 60515
# Processing image 5609
# Number of data in SVM dataset: 60711
# Number of data in regression dataset: 60711
# Processing image 5610
# Number of data in SVM dataset: 60928
# Number of data in regression dataset: 60928
# Processing image 5611
# Number of data in SVM dataset: 61069
# Number of data in regression dataset: 61069
# Processing image 5612
# Number of data in SVM dataset: 61349
# Number of data in regression dataset: 61349
# Processing image 5613
# Number of data in SVM dataset: 61555
# Number of data in regression dataset: 61555
# Processing image 5614
# Number of data in SVM dataset: 61817
# Number of data in regression dataset: 61817
# Processing image 5615
# Number of data in SVM dataset: 61990
# Number of data in regression dataset: 61990
# Processing image 5616
# Number of data in SVM dataset: 62030
# Number of data in regression dataset: 62030
# Processing image 5617
# Number of data in SVM dataset: 62339
# Number of data in regression dataset: 62339
# Processing image 5618
# Number of data in SVM dataset: 62526
# Number of data in regression dataset: 62526
# Processing image 5619
# Number of data in SVM dataset: 62539
# Number of data in regression dataset: 62539
# Processing image 5620
# Number of data in SVM dataset: 62777
# Number of data in regression dataset: 62777
# Processing image 5621
# Number of data in SVM dataset: 62988
# Number of data in regression dataset: 62988
# Processing image 5622
# Number of data in SVM dataset: 63131
# Number of data in regression dataset: 63131
# Processing image 5623
# Number of data in SVM dataset: 63235
# Number of data in regression dataset: 63235
# Processing image 5624
# Number of data in SVM dataset: 63382
# Number of data in regression dataset: 63382
# Processing image 5625
# Number of data in SVM dataset: 63392
# Number of data in regression dataset: 63392
# Processing image 5626
# Number of data in SVM dataset: 63463
# Number of data in regression dataset: 63463
# Processing image 5627
# Number of data in SVM dataset: 63525
# Number of data in regression dataset: 63525
# Processing image 5628
# Number of data in SVM dataset: 63596
# Number of data in regression dataset: 63596
# Processing image 5629
# Number of data in SVM dataset: 63613
# Number of data in regression dataset: 63613
# Processing image 5630
# Number of data in SVM dataset: 63699
# Number of data in regression dataset: 63699
# Processing image 5631
# Number of data in SVM dataset: 63936
# Number of data in regression dataset: 63936
# Processing image 5632
# Number of data in SVM dataset: 64086
# Number of data in regression dataset: 64086
# Processing image 5633
# Number of data in SVM dataset: 64173
# Number of data in regression dataset: 64173
# Processing image 5634
# Number of data in SVM dataset: 64430
# Number of data in regression dataset: 64430
# Processing image 5635
# Number of data in SVM dataset: 64509
# Number of data in regression dataset: 64509
# Processing image 5636
# Number of data in SVM dataset: 64764
# Number of data in regression dataset: 64764
# Processing image 5637
# Number of data in SVM dataset: 64860
# Number of data in regression dataset: 64860
# Processing image 5638
# Number of data in SVM dataset: 64924
# Number of data in regression dataset: 64924
# Processing image 5639
# Number of data in SVM dataset: 65227
# Number of data in regression dataset: 65227
# Processing image 5640
# Number of data in SVM dataset: 65486
# Number of data in regression dataset: 65486
# Processing image 5641
# Number of data in SVM dataset: 65638
# Number of data in regression dataset: 65638
# Processing image 5642
# Number of data in SVM dataset: 65776
# Number of data in regression dataset: 65776
# Processing image 5643
# Number of data in SVM dataset: 66123
# Number of data in regression dataset: 66123
# Processing image 5644
# Number of data in SVM dataset: 66312
# Number of data in regression dataset: 66312
# Processing image 5645
# Number of data in SVM dataset: 66395
# Number of data in regression dataset: 66395
# Processing image 5646
# Number of data in SVM dataset: 66626
# Number of data in regression dataset: 66626
# Processing image 5647
# Number of data in SVM dataset: 66772
# Number of data in regression dataset: 66772
# Processing image 5648
# Number of data in SVM dataset: 67127
# Number of data in regression dataset: 67127
# Processing image 5649
# Number of data in SVM dataset: 67389
# Number of data in regression dataset: 67389
# Processing image 5650
# Number of data in SVM dataset: 67390
# Number of data in regression dataset: 67390
# Processing image 5651
# Number of data in SVM dataset: 67631
# Number of data in regression dataset: 67631
# Processing image 5652
# Number of data in SVM dataset: 67809
# Number of data in regression dataset: 67809
# Processing image 5653
# Number of data in SVM dataset: 67905
# Number of data in regression dataset: 67905
# Processing image 5654
# Number of data in SVM dataset: 68016
# Number of data in regression dataset: 68016
# Processing image 5655
# Number of data in SVM dataset: 68318
# Number of data in regression dataset: 68318
# Processing image 5656
# Number of data in SVM dataset: 68329
# Number of data in regression dataset: 68329
# Processing image 5657
# Number of data in SVM dataset: 68511
# Number of data in regression dataset: 68511
# Processing image 5658
# Number of data in SVM dataset: 68512
# Number of data in regression dataset: 68512
# Processing image 5659
# Number of data in SVM dataset: 68827
# Number of data in regression dataset: 68827
# Processing image 5660
# Number of data in SVM dataset: 69023
# Number of data in regression dataset: 69023
# Processing image 5661
# Number of data in SVM dataset: 69035
# Number of data in regression dataset: 69035
# Processing image 5662
# Number of data in SVM dataset: 69180
# Number of data in regression dataset: 69180
# Processing image 5663
# Number of data in SVM dataset: 69408
# Number of data in regression dataset: 69408
# Processing image 5664
# Number of data in SVM dataset: 69789
# Number of data in regression dataset: 69789
# Processing image 5665
# Number of data in SVM dataset: 69845
# Number of data in regression dataset: 69845
# Processing image 5666
# Number of data in SVM dataset: 69847
# Number of data in regression dataset: 69847
# Processing image 5667
# Number of data in SVM dataset: 70071
# Number of data in regression dataset: 70071
# Processing image 5668
# Number of data in SVM dataset: 70304
# Number of data in regression dataset: 70304
# Processing image 5669
# Number of data in SVM dataset: 70319
# Number of data in regression dataset: 70319
# Processing image 5670
# Number of data in SVM dataset: 70446
# Number of data in regression dataset: 70446
# Processing image 5671
# Number of data in SVM dataset: 70602
# Number of data in regression dataset: 70602
# Processing image 5672
# Number of data in SVM dataset: 70646
# Number of data in regression dataset: 70646
# Processing image 5673
# Number of data in SVM dataset: 70880
# Number of data in regression dataset: 70880
# Processing image 5674
# Number of data in SVM dataset: 70899
# Number of data in regression dataset: 70899
# Processing image 5675
# Number of data in SVM dataset: 71016
# Number of data in regression dataset: 71016
# Processing image 5676
# Number of data in SVM dataset: 71214
# Number of data in regression dataset: 71214
# Processing image 5677
# Number of data in SVM dataset: 71240
# Number of data in regression dataset: 71240
# Processing image 5678
# Number of data in SVM dataset: 71603
# Number of data in regression dataset: 71603
# Processing image 5679
# Number of data in SVM dataset: 71627
# Number of data in regression dataset: 71627
# Processing image 5680
# Number of data in SVM dataset: 71790
# Number of data in regression dataset: 71790
# Processing image 5681
# Number of data in SVM dataset: 72057
# Number of data in regression dataset: 72057
# Processing image 5682
# Number of data in SVM dataset: 72128
# Number of data in regression dataset: 72128
# Processing image 5683
# Number of data in SVM dataset: 72270
# Number of data in regression dataset: 72270
# Processing image 5684
# Number of data in SVM dataset: 72576
# Number of data in regression dataset: 72576
# Processing image 5685
# Number of data in SVM dataset: 72777
# Number of data in regression dataset: 72777
# Processing image 5686
# Number of data in SVM dataset: 72934
# Number of data in regression dataset: 72934
# Processing image 5687
# Number of data in SVM dataset: 72948
# Number of data in regression dataset: 72948
# Processing image 5688
# Number of data in SVM dataset: 72952
# Number of data in regression dataset: 72952
# Processing image 5689
# Number of data in SVM dataset: 73131
# Number of data in regression dataset: 73131
# Processing image 5690
# Number of data in SVM dataset: 73157
# Number of data in regression dataset: 73157
# Processing image 5691
# Number of data in SVM dataset: 73214
# Number of data in regression dataset: 73214
# Processing image 5692
# Number of data in SVM dataset: 73349
# Number of data in regression dataset: 73349
# Processing image 5693
# Number of data in SVM dataset: 73425
# Number of data in regression dataset: 73425
# Processing image 5694
# Number of data in SVM dataset: 73661
# Number of data in regression dataset: 73661
# Processing image 5695
# Number of data in SVM dataset: 73823
# Number of data in regression dataset: 73823
# Processing image 5696
# Number of data in SVM dataset: 73919
# Number of data in regression dataset: 73919
# Processing image 5697
# Number of data in SVM dataset: 74134
# Number of data in regression dataset: 74134
# Processing image 5698
# Number of data in SVM dataset: 74179
# Number of data in regression dataset: 74179
# Processing image 5699
# Number of data in SVM dataset: 74262
# Number of data in regression dataset: 74262
# Processing image 5700
# Number of data in SVM dataset: 74291
# Number of data in regression dataset: 74291
# Processing image 5701
# Number of data in SVM dataset: 74416
# Number of data in regression dataset: 74416
# Processing image 5702
# Number of data in SVM dataset: 74514
# Number of data in regression dataset: 74514
# Processing image 5703
# Number of data in SVM dataset: 74707
# Number of data in regression dataset: 74707
# Processing image 5704
# Number of data in SVM dataset: 74719
# Number of data in regression dataset: 74719
# Processing image 5705
# Number of data in SVM dataset: 75044
# Number of data in regression dataset: 75044
# Processing image 5706
# Number of data in SVM dataset: 75064
# Number of data in regression dataset: 75064
# Processing image 5707
# Number of data in SVM dataset: 75170
# Number of data in regression dataset: 75170
# Processing image 5708
# Number of data in SVM dataset: 75295
# Number of data in regression dataset: 75295
# Processing image 5709
# Number of data in SVM dataset: 75589
# Number of data in regression dataset: 75589
# Processing image 5710
# Number of data in SVM dataset: 75764
# Number of data in regression dataset: 75764
# Processing image 5711
# Number of data in SVM dataset: 75850
# Number of data in regression dataset: 75850
# Processing image 5712
# Number of data in SVM dataset: 76125
# Number of data in regression dataset: 76125
# Processing image 5713
# Number of data in SVM dataset: 76300
# Number of data in regression dataset: 76300
# Processing image 5714
# Number of data in SVM dataset: 76380
# Number of data in regression dataset: 76380
# Processing image 5715
# Number of data in SVM dataset: 76632
# Number of data in regression dataset: 76632
# Processing image 5716
# Number of data in SVM dataset: 76664
# Number of data in regression dataset: 76664
# Processing image 5717
# Number of data in SVM dataset: 76678
# Number of data in regression dataset: 76678

# %%
# Size in MB of svm_dataset and regression_dataset in memory

print('Size of svm_dataset:', sys.getsizeof(svm_dataset) / 1024 / 1024, 'MB')
print('Size of regression_dataset:', sys.getsizeof(regression_dataset) / 1024 / 1024, 'MB')
# Out:
# Size of svm_dataset: 0.5364303588867188 MB
# Size of regression_dataset: 0.5364303588867188 MB

# %%
with open('svm_dataset_2.pkl', 'rb') as f:
    svm_dataset_one = pickle.load(f)

# %%
# save the svm_dataset and regression_dataset to disk
with open('svm_dataset.pkl', 'wb') as f:
    pickle.dump(svm_dataset, f)

with open('regression_dataset.pkl', 'wb') as f:
    pickle.dump(regression_dataset, f)

# %%
# 2200 images processed and saved to disk in svm_dataset.pkl and regression_dataset.pkl


# 1100 images processed and saved to disk in svm_dataset_2.pkl and regression_dataset_2.pkl
# 1000 images processed and saved to disk in svm_dataset_3.pkl and regression_dataset_3.pkl


# Total 4300 images processed and saved
